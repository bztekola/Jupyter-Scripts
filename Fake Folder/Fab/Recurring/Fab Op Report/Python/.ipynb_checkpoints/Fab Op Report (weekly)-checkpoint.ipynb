# %% [markdown]
# ### About the PDF report
# Sometimes the PDF report will generate and have strange line breaks. If this happens, just rereun the single cell towards the end of this script, under the section header titled "PDF Start"

# %% [markdown]
# ### Change this stuff

# %%
# Do you want to run the script and generate this stuff?
# The script will run regardless of what you choose here
# choose "yes" or "no"
workbook_close = 'yes'
pdf_write = 'yes'

# %% [markdown]
# ### Libraries

# %%
import os
tilde = os.path.expanduser('~')

import sys
sys.path.insert(0, tilde + '/Scripts/Fake Folder/Python Libraries')

from jb_libraries import *
# %matplotlib inline

# %% [markdown]
# ### Script settings

# %%
# get the current date
now = dt.datetime.now()
pretty_now = str(dt.datetime.now().date())

# the weeks in this report begin on wednesday and end on thursday
# here, get the current date, if it's not a thursday, back up to the most recent thursday
d = dt.datetime.now()
i = 0
while d.strftime('%A').lower() != 'thursday':
    d = (now - pd.DateOffset(days = i))
    i += 1
else:
    week_end = str(d.date())

csv_path = tilde + '/Scripts/Fake Folder/Fab/Recurring/Fab Op Report/CSVs/'

image_path = tilde + '/Scripts/Fake Folder/Fab/Recurring/Fab Op Report/Images/'

html_path = tilde + '/Scripts/Fake Folder/Fab/Recurring/Fab Op Report/HTML/'
html_title = 'Fab Op Report.html'

pdf_path = tilde + '/Scripts/Fake Folder/Fab/Recurring/Fab Op Report/Docs/Weekly Reports/'

style_sheet_path = tilde + '/Scripts/Fake Folder/CSS Stylesheets/Recurring Reports Stylesheet.css'

report_dict = {}

workbook_title = 'Fab Op Metric data as of ' + week_end

# %% [markdown]
# ### Get Fab data

# %%
from fab_data import *
# Out:
# == fab_data start ==
#
# WO date nulls even though WO is marked as "completed":
# created
# 0
# scheduled
# 0
# active
# 51
# completed
# 8
# these are stored in the "date_nulls" df and have been fixed
#
# The data shows the following work order counts:
#
# x6,637 unique
# x6,123 completed
# x195 open
# x319 pending
#
# your df is called "fab_data_main"
#
#
# == fab_data end ==

# %% [markdown]
# ### Chart settings

# %%
colors = ['#f2f7f8',
          '#3f312d',
          '#c9cdc7',
          '#3a6e7c',
          '#84b4c0',
          '#364345']

# %% [markdown]
# ### Work Order Counts

# %%
counts = fab_data_main.groupby('wo status')[['wo id']].nunique()
counts.columns = ['work order counts']
counts.sort_values('work order counts', ascending = False, inplace = True)

counts.loc['Total'] = counts.sum()
counts.reset_index(inplace = True)
counts['wo status'] = [x.title() for x in counts['wo status']]

fmt = [0,'n0']
display(counts.format_(fmt))
report_dict['summary - work order counts'] = counts.format_(fmt).to_html(index = False)
# Out:
#    Wo Status Work Order Counts
# 0  Completed             6,123
# 1    Pending               319
# 2     Active               195
# 3      Total             6,637

# %% [markdown]
# # Begin to assemble the Fab Op Metric
# Recall that this metric covers:
# * work order completion
# * quality
# * reworks
# * in-stock percentage
#
# In what follows we'll get all four parts and put them altogether along with their weights to create the Fab Op Metric.

# %% [markdown]
# # Work Order Creation and Completion
# ### a.k.a. Availability Metric
#  Availability = (50%)(WOs completed / scheduled) + (50%)(WOs completed / active)

# %%
avail_main = fab_data_main[fab_data_main['wo outsourced'] == 'no'].drop_duplicates('wo id', keep = 'first').copy()

# %% [markdown]
# ### For reports

# %%
# group on these columns to get the work order count per week
df1 = avail_main.groupby('wo week scheduled')[['wo id']].count()
df1.columns = ['scheduled']

df2 = avail_main.groupby('wo week active')[['wo id']].count()
df2.columns = ['active']

df3 = avail_main.groupby('wo week completed')[['wo id']].count()
df3.columns = ['completed']

# join them all
df4 = df1.join(df2).join(df3)

# make these columns
df4['completed as % of scheduled'] = df4['completed']/df4['scheduled']
df4['completed as % of active'] = df4['completed']/df4['active']

# get all active WOs
df5 = avail_main[avail_main['wo status'] == 'active'].groupby('wo week scheduled')[['wo id']].nunique()    
df5.columns = ['active wos']

# join
avail = df4.join(df5)
avail.fillna(0, inplace = True)
avail = avail[avail.index <= week_end]

# this is the Availability metric of the Fab Op Metric
w1 = 0.50
w2 = 1 - w1
avail['availability %'] = w1 * avail['completed as % of scheduled'] + w2 * avail['completed as % of active']

# %% [markdown]
# ### Availability Summary

# %%
# a function that I wrote which takes in a dataframe, finds the mean, then formats the 
    # output according to the list that was passed in
fmt = ['n0'] * 3 + ['p1'] * 2 + ['n0','p1']
print(jb_mean(avail.iloc[-53:], fmt))

avail.tail(8).format_(fmt)
# Out:
#                               mean
# Scheduled                       24
# Active                          24
# Completed                       22
# Completed As % Of Scheduled  98.6%
# Completed As % Of Active     97.4%
# Active Wos                       3
# Availability %               98.0%
#                   Scheduled Active Completed Completed As % Of Scheduled  \
# wo week scheduled
# 2019-04-25               25     25        31                      124.0%
# 2019-05-02               32     32        29                       90.6%
# 2019-05-09               30     29        45                      150.0%
# 2019-05-16               26     27        24                       92.3%
# 2019-05-23               28     26        31                      110.7%
# 2019-05-30               15     15         6                       40.0%
# 2019-06-06               25     24        17                       68.0%
# 2019-06-13               27     27        20                       74.1%
#
#                   Completed As % Of Active Active Wos Availability %
# wo week scheduled
# 2019-04-25                          124.0%         13         124.0%
# 2019-05-02                           90.6%         15          90.6%
# 2019-05-09                          155.2%         15         152.6%
# 2019-05-16                           88.9%         15          90.6%
# 2019-05-23                          119.2%         25         115.0%
# 2019-05-30                           40.0%         11          40.0%
# 2019-06-06                           70.8%         20          69.4%
# 2019-06-13                           74.1%         23          74.1%

# %% [markdown]
# ### Availability plot

# %%
chart = avail.tail(12).copy() # plot just the most recent 16 weeks
fig, ax = plt.subplots(figsize = (20,5))

chart[['scheduled','active','completed']].plot(kind = 'bar',
                                              ax = ax,
                                              color = colors[1:4],
                                              edgecolor = 'black',
                                              width = 0.75)

ax.set_title('Availability Metric Over Time', fontsize = 30, y = 1.02)
ax.set_yticklabels(['{:,.0f}'.format(x) for x in ax.get_yticks()], fontsize = 20)
ax.set_ylabel('Counts', fontsize = 20)
ax.set_xlabel('Week Ending',fontsize = 20, labelpad = 15)
ax.legend(['Scheduled','Active','Completed'],fontsize = 20, bbox_to_anchor = (-0.05, 1))
ax.set_facecolor(colors[0])

ax2 = ax.twinx()
chart['availability %'].plot(ax = ax2,
                             ls = '--', 
                             lw = 2,
                             marker = 'o',
                             mew = 5,
                             color = colors[5])

ax2.set_yticklabels(['{:,.0f}%'.format(x * 100) for x in ax2.get_yticks()], fontsize = 20)
ax2.set_ylabel('Availability Metric', fontsize = 20, rotation = 270, labelpad = 20)

ls = [x.get_text() for x in ax.get_xticklabels()]
ls2 = jb_dates(pd.Series(ls), 'date xticks')
ax.set_xticklabels(ls2, fontsize = 15, rotation = 0)

ax2.legend(['Availability %'],fontsize = 20, bbox_to_anchor = (-0.05, 0.15))

plt.savefig(image_path + ax.get_title(), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# # Quality
# Quality = Good Units / Total Units

# %%
# get main data for this subsection
# exclude reworks
quality_main = fab_data_main[(fab_data_main['rework id'] == 0)].drop_duplicates('process id', keep = 'first').copy()

# get the count of rejects
df1 = quality_main.groupby(['process week end','process group'])[['process qty reject']].sum().unstack(1).fillna(0)
df1.columns = df1.columns.droplevel(0)
df1['total qty rejected'] = df1.sum(1)

# get total qty in
df2 = quality_main.groupby('process week end')[['process qty in']].sum()
df2.columns = ['total qty in']

# join the two
df3 = df1.join(df2)

# count how many steps ocurred in the manufacturing process
df4 = quality_main.groupby(['process week end','process group'])[['process group']].count().unstack(1).fillna(0)
df4.columns = df4.columns.droplevel(0)
df4['total steps'] = df4.sum(1)    

# join
df5 = df3.join(df4['total steps'])    

# get some stats
df5['reject %'] = df5['total qty rejected']/df5['total qty in']
df5['quality %'] = 1 - df5['reject %']

# get the unique work order count
df6 = quality_main.groupby('process week end')[['wo id']].nunique()
df6.columns = ['unique wo count']

# join
df7 = df5.join(df6)

# get the count for the fabrication step only
df8 = quality_main[quality_main['process group'] == 'fabricate'].groupby('process week end')[['process qty in']].sum()
df8.columns = ['fabrication qty in']

# join it and get machine_yield
df9 = df7.join(df8)
df9['machine yield'] = 1 - (df9['fabricate']/df9['fabrication qty in'])

qual = df9.copy()
qual = qual[qual.index <= week_end]

# %% [markdown]
# ### Quality Summary

# %%
fmt = ['n0'] * 10 + ['p1'] * 2 + ['n0'] * 2 + ['p1']

print(jb_mean(qual.iloc[-53:], fmt))
      
qual.tail(8).format_(fmt)
# Out:
#                        mean
# Fabricate               255
# Kitten                   41
# Outsource                 0
# Prep                     12
# Qa                        0
# Secondary                 1
# Test                    375
# Total Qty Rejected      685
# Total Qty In        109,166
# Total Steps             125
# Reject %               0.7%
# Quality %             99.3%
# Unique Wo Count          55
# Fabrication Qty In   18,027
# Machine Yield         98.5%
#                  Fabricate Kitten Outsource Prep Qa Secondary Test  \
# process week end
# 2019-04-25               1      7         0    0  0         0  506
# 2019-05-02             132      5         0    2  0         0  360
# 2019-05-09             632    216         0    1  0         0  378
# 2019-05-16              17     11         0    1  0         2  715
# 2019-05-23               0      6         0    1  2         0  497
# 2019-05-30             205      7         0    1  0         0  107
# 2019-06-06             509     52         0   13  1         0  298
# 2019-06-13           1,505      1         0    0  1        20  649
#
#                  Total Qty Rejected Total Qty In Total Steps Reject %  \
# process week end
# 2019-04-25                      514      106,084         153     0.5%
# 2019-05-02                      499      112,343         157     0.4%
# 2019-05-09                    1,227      216,483         216     0.6%
# 2019-05-16                      746      110,120         134     0.7%
# 2019-05-23                      506      301,889         169     0.2%
# 2019-05-30                      320       32,714          61     1.0%
# 2019-06-06                      873       79,622         105     1.1%
# 2019-06-13                    2,176       90,882         124     2.4%
#
#                  Quality % Unique Wo Count Fabrication Qty In Machine Yield
# process week end
# 2019-04-25           99.5%              68             19,791        100.0%
# 2019-05-02           99.6%              70             22,611         99.4%
# 2019-05-09           99.4%              83             23,824         97.3%
# 2019-05-16           99.3%              59             13,948         99.9%
# 2019-05-23           99.8%              73             28,412        100.0%
# 2019-05-30           99.0%              30             11,367         98.2%
# 2019-06-06           98.9%              46             15,533         96.7%
# 2019-06-13           97.6%              56             21,703         93.1%

# %% [markdown]
# ### Quality Plot

# %%
fig, ax = plt.subplots(figsize = (20,5))

n = 16 # plot the most recent 16 weeks
x = range(n)
y1 = qual['quality %'].tail(n)
y2 = qual['machine yield'].tail(n)

ax.plot(x, y1,
       lw = 5,
       marker = 'o',
       mew = 5,
       color = colors[1])

ax.plot(x, y2,
       lw = 5,
       ls = '--',
       marker = 'o',
       mew = 5,
       color = colors[4])

ax.set_xticks(x)
ls = list(qual.index[-n:])
ls2 = list(jb_dates(pd.Series(ls), 'date xticks'))
ax.set_xticklabels(ls2, fontsize = 15, rotation = 0)
ax.set_xlabel('Week Ending', fontsize = 20, labelpad = 15)

m1 = ax.get_yticks().min()
m2 = ax.get_yticks().max()
yticks = np.arange(m1, m2, 0.01)
ax.set_yticks(yticks)
ax.set_yticklabels(['{:,.0f}%'.format(x * 100) for x in ax.get_yticks()], fontsize = 20)

ax.set_title('Quality Metric and Machine Yield', fontsize = 30, y = 1.02)
ax.legend(['Quality Metric','Machine Yield'], fontsize = 20)
ax.set_facecolor(colors[0])
ax.grid(alpha = 0.5)

plt.savefig(image_path + ax.get_title(), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Units rejected during the latest week
# Zoom in to the current week to see which parts had the most rejections

# %%
rej1 = quality_main[quality_main['process week end'] == week_end].copy()

for col in ['part id','sku id']:
    rej1[col] = [int(x) for x in rej1[col]]
    
rej2 = rej1.groupby(['sku id','part id','products name','process group'])[['process qty reject']].sum().unstack(3).fillna(0)
rej2.columns = rej2.columns.droplevel(0)
rej2['row total'] = rej2.sum(1)
rej2 = rej2.drop(rej2[rej2['row total'] == 0].index)
rej2.sort_values('row total', ascending = False, inplace = True)

rej2.loc[('','','Column Total'),:] = rej2.sum()

t = rej2.iloc[-1]['row total']
print('Total units rejected: {:,.0f}'.format(t))
for col in rej2.columns:
    rej2[col] = [int(x) for x in rej2[col]]

display(rej2)
# Out:
# Total units rejected: 2,176
# /anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py:399: PerformanceWarning: indexing past lexsort depth may impact performance.
#   user_expressions, allow_stdin)
# process group                                                                   fabricate  \
# sku id part id products name
# 9108   746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates            711
# 13559  4242    Adafruit PyGamer for MakeCode Arcade, CircuitPython or Arduino         510
# 8621   1904    Adafruit Micro-Lipo Charger for LiPo/LiIon Batt w/MicroUSB Jack          0
# 13232  4145    Assembled Adafruit Prop-Maker FeatherWing                               80
# 8894   2895    Adafruit Non-Latching Mini Relay FeatherWing                            63
# 8872   2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)              50
# 12679  3964    Adafruit VEML6075 UVA UVB and UV Index Sensor Breakout                  40
# 13613  4280    Adafruit DC & Stepper Motor Bonnet for Raspberry Pi                     20
# 8942   3027    Adafruit Feather 32u4 FONA                                               0
# 8529   1551    DS2413 1-Wire Two GPIO Controller Breakout                              25
# 13536  3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2               0
# 8989   3176    Adafruit Feather M0 RFM69HCW Packet Radio - 868 or 915 MHz               0
# 10933  2030    PowerBoost 1000 Basic - 5V USB Boost @ 1000mA from 1.8V+                 0
# 13385  4195    Adafruit 2.13" Monochrome eInk / ePaper Display FeatherWing              0
# 12382  3954    Adafruit NeoTrellis RGB Driver PCB for 4x4 Keypad                        0
# 8693   2219    TFP401 HDMI/DVI Decoder to 40-Pin TTL Breakout - With Touch              0
# 13429  4224    Adafruit eInk Breakout Friend with 32KB SRAM                             0
# 13594  4258    Adafruit LPS35HW Water Resistant Pressure Sensor                         0
# 8597   1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board              4
# 12487  3928    Adafruit CRICKIT for micro:bit                                           2
# 8590   1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket            0
# 9000   3201    Adafruit Ethernet FeatherWing                                            0
# 8665   2088    Adafruit 1.44" Color TFT LCD Display with MicroSD Card breakout          0
# 13645  4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates              0
#                Column Total                                                          1505
#
# process group                                                                   kitten  \
# sku id part id products name
# 9108   746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates           0
# 13559  4242    Adafruit PyGamer for MakeCode Arcade, CircuitPython or Arduino        0
# 8621   1904    Adafruit Micro-Lipo Charger for LiPo/LiIon Batt w/MicroUSB Jack       0
# 13232  4145    Assembled Adafruit Prop-Maker FeatherWing                             0
# 8894   2895    Adafruit Non-Latching Mini Relay FeatherWing                          0
# 8872   2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)            0
# 12679  3964    Adafruit VEML6075 UVA UVB and UV Index Sensor Breakout                0
# 13613  4280    Adafruit DC & Stepper Motor Bonnet for Raspberry Pi                   0
# 8942   3027    Adafruit Feather 32u4 FONA                                            0
# 8529   1551    DS2413 1-Wire Two GPIO Controller Breakout                            0
# 13536  3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2            0
# 8989   3176    Adafruit Feather M0 RFM69HCW Packet Radio - 868 or 915 MHz            0
# 10933  2030    PowerBoost 1000 Basic - 5V USB Boost @ 1000mA from 1.8V+              0
# 13385  4195    Adafruit 2.13" Monochrome eInk / ePaper Display FeatherWing           0
# 12382  3954    Adafruit NeoTrellis RGB Driver PCB for 4x4 Keypad                     0
# 8693   2219    TFP401 HDMI/DVI Decoder to 40-Pin TTL Breakout - With Touch           0
# 13429  4224    Adafruit eInk Breakout Friend with 32KB SRAM                          0
# 13594  4258    Adafruit LPS35HW Water Resistant Pressure Sensor                      0
# 8597   1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board           0
# 12487  3928    Adafruit CRICKIT for micro:bit                                        0
# 8590   1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket         0
# 9000   3201    Adafruit Ethernet FeatherWing                                         1
# 8665   2088    Adafruit 1.44" Color TFT LCD Display with MicroSD Card breakout       0
# 13645  4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates           0
#                Column Total                                                          1
#
# process group                                                                   outsource  \
# sku id part id products name
# 9108   746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates              0
# 13559  4242    Adafruit PyGamer for MakeCode Arcade, CircuitPython or Arduino           0
# 8621   1904    Adafruit Micro-Lipo Charger for LiPo/LiIon Batt w/MicroUSB Jack          0
# 13232  4145    Assembled Adafruit Prop-Maker FeatherWing                                0
# 8894   2895    Adafruit Non-Latching Mini Relay FeatherWing                             0
# 8872   2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)               0
# 12679  3964    Adafruit VEML6075 UVA UVB and UV Index Sensor Breakout                   0
# 13613  4280    Adafruit DC & Stepper Motor Bonnet for Raspberry Pi                      0
# 8942   3027    Adafruit Feather 32u4 FONA                                               0
# 8529   1551    DS2413 1-Wire Two GPIO Controller Breakout                               0
# 13536  3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2               0
# 8989   3176    Adafruit Feather M0 RFM69HCW Packet Radio - 868 or 915 MHz               0
# 10933  2030    PowerBoost 1000 Basic - 5V USB Boost @ 1000mA from 1.8V+                 0
# 13385  4195    Adafruit 2.13" Monochrome eInk / ePaper Display FeatherWing              0
# 12382  3954    Adafruit NeoTrellis RGB Driver PCB for 4x4 Keypad                        0
# 8693   2219    TFP401 HDMI/DVI Decoder to 40-Pin TTL Breakout - With Touch              0
# 13429  4224    Adafruit eInk Breakout Friend with 32KB SRAM                             0
# 13594  4258    Adafruit LPS35HW Water Resistant Pressure Sensor                         0
# 8597   1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board              0
# 12487  3928    Adafruit CRICKIT for micro:bit                                           0
# 8590   1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket            0
# 9000   3201    Adafruit Ethernet FeatherWing                                            0
# 8665   2088    Adafruit 1.44" Color TFT LCD Display with MicroSD Card breakout          0
# 13645  4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates              0
#                Column Total                                                             0
#
# process group                                                                   prep  \
# sku id part id products name
# 9108   746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates         0
# 13559  4242    Adafruit PyGamer for MakeCode Arcade, CircuitPython or Arduino      0
# 8621   1904    Adafruit Micro-Lipo Charger for LiPo/LiIon Batt w/MicroUSB Jack     0
# 13232  4145    Assembled Adafruit Prop-Maker FeatherWing                           0
# 8894   2895    Adafruit Non-Latching Mini Relay FeatherWing                        0
# 8872   2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)          0
# 12679  3964    Adafruit VEML6075 UVA UVB and UV Index Sensor Breakout              0
# 13613  4280    Adafruit DC & Stepper Motor Bonnet for Raspberry Pi                 0
# 8942   3027    Adafruit Feather 32u4 FONA                                          0
# 8529   1551    DS2413 1-Wire Two GPIO Controller Breakout                          0
# 13536  3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2          0
# 8989   3176    Adafruit Feather M0 RFM69HCW Packet Radio - 868 or 915 MHz          0
# 10933  2030    PowerBoost 1000 Basic - 5V USB Boost @ 1000mA from 1.8V+            0
# 13385  4195    Adafruit 2.13" Monochrome eInk / ePaper Display FeatherWing         0
# 12382  3954    Adafruit NeoTrellis RGB Driver PCB for 4x4 Keypad                   0
# 8693   2219    TFP401 HDMI/DVI Decoder to 40-Pin TTL Breakout - With Touch         0
# 13429  4224    Adafruit eInk Breakout Friend with 32KB SRAM                        0
# 13594  4258    Adafruit LPS35HW Water Resistant Pressure Sensor                    0
# 8597   1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board         0
# 12487  3928    Adafruit CRICKIT for micro:bit                                      0
# 8590   1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket       0
# 9000   3201    Adafruit Ethernet FeatherWing                                       0
# 8665   2088    Adafruit 1.44" Color TFT LCD Display with MicroSD Card breakout     0
# 13645  4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates         0
#                Column Total                                                        0
#
# process group                                                                   qa  \
# sku id part id products name
# 9108   746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates       0
# 13559  4242    Adafruit PyGamer for MakeCode Arcade, CircuitPython or Arduino    0
# 8621   1904    Adafruit Micro-Lipo Charger for LiPo/LiIon Batt w/MicroUSB Jack   0
# 13232  4145    Assembled Adafruit Prop-Maker FeatherWing                         0
# 8894   2895    Adafruit Non-Latching Mini Relay FeatherWing                      0
# 8872   2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)        0
# 12679  3964    Adafruit VEML6075 UVA UVB and UV Index Sensor Breakout            0
# 13613  4280    Adafruit DC & Stepper Motor Bonnet for Raspberry Pi               0
# 8942   3027    Adafruit Feather 32u4 FONA                                        0
# 8529   1551    DS2413 1-Wire Two GPIO Controller Breakout                        0
# 13536  3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2        0
# 8989   3176    Adafruit Feather M0 RFM69HCW Packet Radio - 868 or 915 MHz        0
# 10933  2030    PowerBoost 1000 Basic - 5V USB Boost @ 1000mA from 1.8V+          0
# 13385  4195    Adafruit 2.13" Monochrome eInk / ePaper Display FeatherWing       0
# 12382  3954    Adafruit NeoTrellis RGB Driver PCB for 4x4 Keypad                 0
# 8693   2219    TFP401 HDMI/DVI Decoder to 40-Pin TTL Breakout - With Touch       0
# 13429  4224    Adafruit eInk Breakout Friend with 32KB SRAM                      0
# 13594  4258    Adafruit LPS35HW Water Resistant Pressure Sensor                  0
# 8597   1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board       0
# 12487  3928    Adafruit CRICKIT for micro:bit                                    0
# 8590   1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket     0
# 9000   3201    Adafruit Ethernet FeatherWing                                     0
# 8665   2088    Adafruit 1.44" Color TFT LCD Display with MicroSD Card breakout   1
# 13645  4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates       0
#                Column Total                                                      1
#
# process group                                                                   secondary  \
# sku id part id products name
# 9108   746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates              0
# 13559  4242    Adafruit PyGamer for MakeCode Arcade, CircuitPython or Arduino           0
# 8621   1904    Adafruit Micro-Lipo Charger for LiPo/LiIon Batt w/MicroUSB Jack          0
# 13232  4145    Assembled Adafruit Prop-Maker FeatherWing                                0
# 8894   2895    Adafruit Non-Latching Mini Relay FeatherWing                             0
# 8872   2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)               0
# 12679  3964    Adafruit VEML6075 UVA UVB and UV Index Sensor Breakout                   0
# 13613  4280    Adafruit DC & Stepper Motor Bonnet for Raspberry Pi                     20
# 8942   3027    Adafruit Feather 32u4 FONA                                               0
# 8529   1551    DS2413 1-Wire Two GPIO Controller Breakout                               0
# 13536  3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2               0
# 8989   3176    Adafruit Feather M0 RFM69HCW Packet Radio - 868 or 915 MHz               0
# 10933  2030    PowerBoost 1000 Basic - 5V USB Boost @ 1000mA from 1.8V+                 0
# 13385  4195    Adafruit 2.13" Monochrome eInk / ePaper Display FeatherWing              0
# 12382  3954    Adafruit NeoTrellis RGB Driver PCB for 4x4 Keypad                        0
# 8693   2219    TFP401 HDMI/DVI Decoder to 40-Pin TTL Breakout - With Touch              0
# 13429  4224    Adafruit eInk Breakout Friend with 32KB SRAM                             0
# 13594  4258    Adafruit LPS35HW Water Resistant Pressure Sensor                         0
# 8597   1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board              0
# 12487  3928    Adafruit CRICKIT for micro:bit                                           0
# 8590   1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket            0
# 9000   3201    Adafruit Ethernet FeatherWing                                            0
# 8665   2088    Adafruit 1.44" Color TFT LCD Display with MicroSD Card breakout          0
# 13645  4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates              0
#                Column Total                                                            20
#
# process group                                                                   test  \
# sku id part id products name
# 9108   746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates        28
# 13559  4242    Adafruit PyGamer for MakeCode Arcade, CircuitPython or Arduino      0
# 8621   1904    Adafruit Micro-Lipo Charger for LiPo/LiIon Batt w/MicroUSB Jack   477
# 13232  4145    Assembled Adafruit Prop-Maker FeatherWing                           0
# 8894   2895    Adafruit Non-Latching Mini Relay FeatherWing                        0
# 8872   2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)          7
# 12679  3964    Adafruit VEML6075 UVA UVB and UV Index Sensor Breakout              0
# 13613  4280    Adafruit DC & Stepper Motor Bonnet for Raspberry Pi                 0
# 8942   3027    Adafruit Feather 32u4 FONA                                         40
# 8529   1551    DS2413 1-Wire Two GPIO Controller Breakout                          0
# 13536  3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2         22
# 8989   3176    Adafruit Feather M0 RFM69HCW Packet Radio - 868 or 915 MHz         19
# 10933  2030    PowerBoost 1000 Basic - 5V USB Boost @ 1000mA from 1.8V+           13
# 13385  4195    Adafruit 2.13" Monochrome eInk / ePaper Display FeatherWing        11
# 12382  3954    Adafruit NeoTrellis RGB Driver PCB for 4x4 Keypad                  10
# 8693   2219    TFP401 HDMI/DVI Decoder to 40-Pin TTL Breakout - With Touch        10
# 13429  4224    Adafruit eInk Breakout Friend with 32KB SRAM                        5
# 13594  4258    Adafruit LPS35HW Water Resistant Pressure Sensor                    4
# 8597   1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board         0
# 12487  3928    Adafruit CRICKIT for micro:bit                                      0
# 8590   1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket       2
# 9000   3201    Adafruit Ethernet FeatherWing                                       0
# 8665   2088    Adafruit 1.44" Color TFT LCD Display with MicroSD Card breakout     0
# 13645  4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates         1
#                Column Total                                                      649
#
# process group                                                                   row total
# sku id part id products name
# 9108   746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates            739
# 13559  4242    Adafruit PyGamer for MakeCode Arcade, CircuitPython or Arduino         510
# 8621   1904    Adafruit Micro-Lipo Charger for LiPo/LiIon Batt w/MicroUSB Jack        477
# 13232  4145    Assembled Adafruit Prop-Maker FeatherWing                               80
# 8894   2895    Adafruit Non-Latching Mini Relay FeatherWing                            63
# 8872   2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)              57
# 12679  3964    Adafruit VEML6075 UVA UVB and UV Index Sensor Breakout                  40
# 13613  4280    Adafruit DC & Stepper Motor Bonnet for Raspberry Pi                     40
# 8942   3027    Adafruit Feather 32u4 FONA                                              40
# 8529   1551    DS2413 1-Wire Two GPIO Controller Breakout                              25
# 13536  3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2              22
# 8989   3176    Adafruit Feather M0 RFM69HCW Packet Radio - 868 or 915 MHz              19
# 10933  2030    PowerBoost 1000 Basic - 5V USB Boost @ 1000mA from 1.8V+                13
# 13385  4195    Adafruit 2.13" Monochrome eInk / ePaper Display FeatherWing             11
# 12382  3954    Adafruit NeoTrellis RGB Driver PCB for 4x4 Keypad                       10
# 8693   2219    TFP401 HDMI/DVI Decoder to 40-Pin TTL Breakout - With Touch             10
# 13429  4224    Adafruit eInk Breakout Friend with 32KB SRAM                             5
# 13594  4258    Adafruit LPS35HW Water Resistant Pressure Sensor                         4
# 8597   1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board              4
# 12487  3928    Adafruit CRICKIT for micro:bit                                           2
# 8590   1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket            2
# 9000   3201    Adafruit Ethernet FeatherWing                                            1
# 8665   2088    Adafruit 1.44" Color TFT LCD Display with MicroSD Card breakout          1
# 13645  4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates              1
#                Column Total                                                          2176

# %% [markdown]
# ### Z scores of rejected qty per step
# Since the total number of units manufactured each week changes, we cannot directly compare the number of units rejected per week. We must put them all on the same footing, so to speak, and we will do this by getting their z scores before we compare them directly.

# %%
z = qual.iloc[:,:7]

mean = z.mean()
s = z.std()

z2 = (z - mean)/s

z2.tail(8).format_(['n2'] * len(z2.columns))
# Out:
#                  Fabricate Kitten Outsource   Prep     Qa Secondary   Test
# process week end
# 2019-04-25           -0.67  -0.19     -0.11  -0.30  -0.11     -0.13   0.05
# 2019-05-02           -0.32  -0.20     -0.11  -0.28  -0.11     -0.13  -0.38
# 2019-05-09            1.06   0.33     -0.11  -0.29  -0.11     -0.13  -0.32
# 2019-05-16           -0.63  -0.18     -0.11  -0.29  -0.11      0.12   0.67
# 2019-05-23           -0.68  -0.19     -0.11  -0.29  -0.02     -0.13   0.03
# 2019-05-30           -0.12  -0.19     -0.11  -0.29  -0.11     -0.13  -1.12
# 2019-06-06            0.72  -0.08     -0.11  -0.17  -0.06     -0.13  -0.56
# 2019-06-13            3.45  -0.21     -0.11  -0.30  -0.06      2.42   0.48

# %%
fig, ax = plt.subplots()
z2.tail(8).plot(kind = 'bar', 
                figsize = (20,5),
                ax = ax,
                width = .85,
                grid = True,
                edgecolor = 'black')
ax.legend(fontsize = 15, bbox_to_anchor = (-0.05, 1))
ax.set_xlabel('Week Ending', fontsize = 15)
ax.set_title('Z scores of qty rejected per step per week\nover the last 8 weeks', fontsize = 30, y = 1.02)
plt.show()

# %% [markdown]
# ### Rejections with high z scores

# %%
ls = z2.iloc[-1][z2.iloc[-1] > 0.5].index.tolist() # take a closer look at those steps with rejections that are one-half of a stand dev above the mean

if len(ls) > 0:
    a = rej1[(rej1['process group'].isin(ls)) & (rej1['process qty reject'] > 0)]

    b = a.groupby(['process group','part id','wo id'])[['process qty reject']].sum()
    b.reset_index(inplace = True)
    b.sort_values('process qty reject', ascending = False, inplace = True)

    c = pd.DataFrame()
    for p in set(b['process group']):
        df = b[b['process group'] == p].copy()
        q = df['process qty reject'].quantile(0.85)
        df.drop(df[df['process qty reject'] < q].index, inplace = True)
        c = c.append(df, ignore_index = True)

    c['process group'] = c['process group'].str.title()    
    c.set_index(['process group','part id','wo id'], inplace = True)
    c.rename(columns = {'process qty reject':'count of rejections'}, inplace = True)
    c.columns = c.columns.str.title()
    names = list(c.index.names)
    names = [x.title() for x in names]
    c.index.names = names

    s = len(set(b['part id']))
    if s == 1:
        w2 = 'work order is'
    elif s > 1:
        w2 = 'work orders are'
    else:
        pass

    if len(ls) == 1:
        wrt = 'On a step-by-step basis, the {} step incurred some higher than normal rejections. The problematic {} shown in the table below.'.format(ls[0].title(), w2)
    else:
        w3 = ''
        max_ = len(ls) - 1
        for i in range(len(ls)):
            if i != max_:
                w3 += ls[i].title() + ', '
            else:
                w3 += 'and ' + ls[i].title()    
        wrt = 'On a step-by-step basis, the {} steps incurred some higher than normal rejections. The problematic {} shown in the table below.'.format(w3, w2)

    report_dict['quality - high rejection write'] = wrt + '\n' + c.to_html(index = True)
    
else:
    report_dict['quality - high rejection write'] = 'On a step-by-step basis, all rejections counts were below or at their averages.'

# %% [markdown]
# # Rework
# Rework = Successful Reworks / Total Reworks Attempted

# %%
# get main subset
reworks_main = fab_data_main[(fab_data_main['rework id'] > 0) & (fab_data_main['wo status'] == 'completed')].copy()
reworks_main['part id'] = [int(x) for x in reworks_main['part id']]

# get some rework qty data
df1 = reworks_main.groupby('spa week end')[['spa qty in','spa qty out','spa qty reject']].sum()
df1.columns = ['qty attempted','qty out','qty rejected']

# create empty weeks if no reworks were performed
start = df1.index[0]
end = week_end

ix = pd.date_range(start, end, freq = 'D')
ix2 = ix[np.arange(0,len(ix),7)]
ds = pd.DataFrame(index = ix2)
ds.index.names = ['spa week end']
df1 = ds.join(df1)

# get total available to rework
df2 = qual[['total qty rejected']]
df2.columns = ['total qty available']

# join
df3 = df1.join(df2)

# get unique work order count
df4 = reworks_main.groupby('spa week end')[['rework id']].nunique()
df4.columns = ['unique wo count']

# join
df5 = df3.join(df4)

# get these stats
df5['attempted as % of available'] = df5['qty attempted']/df5['total qty available']
df5['reject %'] = df5['qty rejected']/df5['qty attempted']
df5['success %'] = 1 - df5['reject %']
df5.fillna(0, inplace = True)

rework = df5.copy()

# %% [markdown]
# ### Rework summary

# %%
fmt = ['n0'] * 5 + ['p1'] * 3
print(jb_mean(rework.iloc[-53:], fmt))

rework.tail(8).format_(fmt)
# Out:
#                               mean
# Qty Attempted                  286
# Qty Out                         96
# Qty Rejected                   190
# Total Qty Available            685
# Unique Wo Count                 14
# Attempted As % Of Available  48.1%
# Reject %                     46.3%
# Success %                    44.3%
#              Qty Attempted Qty Out Qty Rejected Total Qty Available  \
# spa week end
# 2019-04-25               6       0            6                 514
# 2019-05-02           1,391       0        1,391                 499
# 2019-05-09              53       0           53               1,227
# 2019-05-16              30       0           30                 746
# 2019-05-23              30       0           30                 506
# 2019-05-30              57      45           12                 320
# 2019-06-06               0       0            0                 873
# 2019-06-13             762       8          754               2,176
#
#              Unique Wo Count Attempted As % Of Available Reject % Success %
# spa week end
# 2019-04-25                 1                        1.2%   100.0%      0.0%
# 2019-05-02                54                      278.8%   100.0%      0.0%
# 2019-05-09                 2                        4.3%   100.0%      0.0%
# 2019-05-16                 2                        4.0%   100.0%      0.0%
# 2019-05-23                 1                        5.9%   100.0%      0.0%
# 2019-05-30                 3                       17.8%    21.1%     78.9%
# 2019-06-06                 0                        0.0%     0.0%      0.0%
# 2019-06-13                77                       35.0%    99.0%      1.0%

# %% [markdown]
# ### Confidence interval for avg success % per week

# %%
jb_conf(rework[['success %']].iloc[-53:]).loc[:'upper'].format_(['p1'])
# Out:
#       Success %
# lower     34.3%
# mean      44.3%
# upper     54.4%

# %% [markdown]
# ### Rework plot

# %%
fig, ax = plt.subplots(figsize = (20,5))

n = 16 # plot the most recent 16 weeks
x = range(n)
y1 = rework['qty attempted'].tail(n)
y2 = rework['success %'].tail(n)

ax.bar(x, y1,
        edgecolor = 'black',
        width = 0.75,
        color = colors[1],
        label = 'qty attempted',
        zorder = 5)

ax.set_yticklabels(['{:,.0f}'.format(x) for x in ax.get_yticks()], fontsize = 20)
ax.set_ylabel('Count', fontsize = 20)
ax.set_title('Count of Reworks Attempted along with the Rework Metric', fontsize = 30, y = 1.02)
ax.legend(['Qty Attempted'], fontsize = 20, bbox_to_anchor = (0.2, -0.2))
ax.set_facecolor(colors[0])

ax2 = ax.twinx()
ax2.plot(x, y2,
       lw = 5,
       ls = '--',
       marker = 'o',
       mew = 5,
       color = colors[4],
       label = 'rework metric')

ax2.set_yticklabels(['{:,.0f}%'.format(x * 100) for x in ax2.get_yticks()], fontsize = 20)
ax2.set_ylabel('Rework Metric', fontsize = 20, rotation = 270, labelpad = 20)
ax2.legend(['Rework Metric'] ,fontsize = 20, bbox_to_anchor = (1, -0.2))
ax.grid(alpha = 0.25)
ax.set_xticks(x)
ls = list(qual.index[-n:])
ls2 = list(jb_dates(pd.Series(ls), 'date xticks'))
ax.set_xticklabels(ls2, fontsize = 15, rotation = 0)
ax.set_xlabel('Week Ending', fontsize = 20, labelpad = 15)

plt.savefig(image_path + ax.get_title(), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Correlation

# %%
x = rework['qty attempted'].fillna(0)
y = rework['reject %'].fillna(0)
plt.scatter(x,y)
plt.ylabel('reject %')
plt.xlabel('qty attempted')
plt.title('scatter plot of qty attempted and reject %')
plt.grid()
plt.show()

# %% [markdown]
# ### Reworks during current week

# %%
cur_reworks = reworks_main[reworks_main['spa week end'] == week_end].groupby(['part id','products name'])[['spa qty in','spa qty reject']].sum()
cur_reworks.columns = ['qty attempted','qty rejected']
cur_reworks['reject %'] = cur_reworks['qty rejected']/cur_reworks['qty attempted']
cur_reworks.sort_values('qty attempted', ascending = False, inplace = True)
cur_reworks.loc[('','column total'),('qty attempted','qty rejected')] = cur_reworks[['qty attempted','qty rejected']].sum()

ls = ['qty attempted','qty out','qty rejected']
if (rework.iloc[-1][ls] == 0).all():
    print('no reworks were performed during w/e {}'.format(week_end))
else:
    rej_per = cur_reworks.iloc[-1]['qty rejected']/cur_reworks.iloc[-1][['qty attempted']].sum()
    cur_reworks['reject %'].fillna(rej_per, inplace = True)
    display(cur_reworks.format_(['n0'] * 2 + ['p1']))
# Out:
#                                                                          Qty Attempted  \
# part id products name
# 3677    Adafruit ItsyBitsy 32u4 - 5V 16MHz                                          63
# 2305    Adafruit DRV2605L Haptic Motor Controller                                   56
# 3966    Adafruit BMP388 - Precision Barometric Pressure and Altimeter               44
# 3386    Adafruit PiRTC - PCF8523 Real Time Clock for Raspberry Pi                   41
# 4097    ADXL343 - Triple-Axis Accelerometer (+-2g/4g/8g/16g) w/ I2C/SPI             40
# 1697    Bluefruit LE - Bluetooth Low Energy (BLE 4.0) - nRF8001 Breakout            37
# 746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates                 28
# 3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2                  23
# 1455    Adafruit 12-Channel 16-bit PWM LED Driver - SPI Interface                   23
# 3787    Adafruit 1.54" 240x240 Wide Angle TFT LCD Display with MicroSD              22
# 3316    Adafruit VL6180X Time of Flight Distance Ranging Sensor (VL6180)            22
# 4224    Adafruit eInk Breakout Friend with 32KB SRAM                                20
# 3134    Adafruit 15x7 CharliePlex LED Matrix Display FeatherWing - Red              20
# 2857    Adafruit Sensirion SHT31-D                                                  19
# 4226    Adafruit INA260 High or Low Side Voltage, Current, Power Sensor             19
# 1982    Adafruit 12-Key Capacitive Touch Sensor Breakout - MPR121                   17
# 1384    GA1A12S202 Log-scale Analog Light Sensor                                    16
# 1411    Adafruit 16-Channel 12-bit PWM/Servo Shield - I2C interface                 15
# 2974    LED Charlieplexed Matrix - 9x16 LEDs - Cool White                           15
# 2748    Adafruit ALS-PT19 Analog Light Sensor Breakout                              14
# 2472    Adafruit 9-DOF Absolute Orientation IMU Fusion Breakout - BNO055            13
# 2772    Adafruit Feather M0 Basic Proto - ATSAMD21 Cortex M0                        13
# 2217    Adafruit Audio FX Sound Board + 2x2W Amp - WAV/OGG Trigger -16MB            12
# 1480    2.2" 18-bit color TFT LCD display with microSD card breakout                11
# 2487    Flora Wearable Bluefruit LE Module                                          11
# 1778    Analog Output K-Type Thermocouple Amplifier - AD8495 Breakout               10
# 2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)                   9
# 3072    Adafruit RFM95W LoRa Radio Transceiver Breakout - 868 or 915 MHz             8
# 1980    Adafruit TSL2591 High Dynamic Range Digital Light Sensor                     7
# 3076    Adafruit Feather 32u4 RFM69HCW Packet Radio - 868 or 915 MHz                 6
# 2946    Adafruit 16x9 Charlieplexed PWM LED Matrix Driver - IS31FL3731               6
# 3249    Adafruit NeoPXL8 FeatherWing for Feather M0 - 8 x DMA NeoPixels!             5
# 3309    Adafruit CP2104 Friend - USB to Serial Converter                             5
# 2923    Adafruit Latching Mini Relay FeatherWing                                     5
# 4172    Adafruit HUZZAH32 â ESP32 Breakout Board                                   4
# 2927    DC Motor + Stepper FeatherWing Add-on For All Feather Boards                 4
# 3650    Adafruit INA219 FeatherWing                                                  4
# 2094    JTAG (2x10 2.54mm) to SWD (2x5 1.27mm) Cable Adapter Board                   4
# 2479    Adafruit Bluefruit LE UART Friend - Bluetooth Low Energy (BLE)               4
# 1651    2.8" TFT Touch Shield for Arduino with Resistive Touch Screen                4
# 1947    2.8" TFT Touch Shield for Arduino w/Capacitive Touch                         3
# 3709    Adafruit SGP30 Air Quality Sensor Breakout - VOC and eCO2                    3
# 904     INA219  High Side DC Current Sensor Breakout - 26V Â±3.2A Max                3
# 3660    Adafruit BME680 - Temperature, Humidity, Pressure and Gas Sensor             3
# 4145    Assembled Adafruit Prop-Maker FeatherWing                                    3
# 1580    Resistive Touch Screen to USB Mouse Controller - AR1100                      3
# 2124    Adafruit LiIon/LiPoly Backpack Add-On for Pro Trinket/ItsyBitsy              3
# 1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board                  3
# 2895    Adafruit Non-Latching Mini Relay FeatherWing                                 3
# 2019    Adafruit Triple-Axis Accelerometer - Â±2/4/8g @ 14-bit - MMA8451             3
# 3343    Adafruit CRICKIT FeatherWing for any Feather                                 2
# 3463    Adafruit Precision NXP 9-DOF Breakout Board                                  2
# 1032    L3GD20H Triple-Axis Gyro Breakout Board - L3GD20/L3G4200 Upgrade             2
# 2345    Adafruit RGB Matrix HAT + RTC for Raspberry Pi - Mini Kit                    2
# 1356    Flora Color Sensor with White Illumination LED - TCS34725                    2
# 2948    LED Charlieplexed Matrix - 9x16 LEDs - Yellow                                2
# 1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket                2
# 3073    Adafruit RFM96W LoRa Radio Transceiver Breakout - 433 MHz                    2
# 2315    Adafruit PiTFT 2.2" HAT Mini Kit - 320x240 2.2" TFT - No Touch               2
# 3013    Adafruit DS3231 Precision RTC Breakout                                       2
# 4090    Adafruit USB C Breakout Board - Downstream Connection                        1
# 4201    Adafruit AirLift â ESP32 WiFi Co-Processor Breakout Board                  1
# 4116    Adafruit PyPortal - CircuitPython Powered Internet Display                   1
# 269     Thermocouple Amplifier MAX31855 breakout board (MAX6675 upgrade)             1
# 3538    Adafruit AMG8833 IR Thermal Camera Breakout                                  1
# 3231    Adafruit LoRa Radio FeatherWing - RFM95W 900 MHz                             1
# 3200    Teensy 3.x Feather Adapter                                                   1
# 466     VCNL4010 Proximity/Light sensor                                              1
# 2746    Adafruit Bluefruit LE Shield - Bluetooth LE for Arduino                      1
# 2327    Adafruit 16-Channel PWM / Servo HAT for Raspberry Pi - Mini Kit              1
# 1381    VS1053 Codec + MicroSD Breakout - MP3/WAV/MIDI/OGG Play + Record             1
# 992     MPL115A2 - I2C Barometric Pressure/Temperature Sensor                        1
# 4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates                  1
#         column total                                                               762
#
#                                                                          Qty Rejected  \
# part id products name
# 3677    Adafruit ItsyBitsy 32u4 - 5V 16MHz                                         63
# 2305    Adafruit DRV2605L Haptic Motor Controller                                  56
# 3966    Adafruit BMP388 - Precision Barometric Pressure and Altimeter              44
# 3386    Adafruit PiRTC - PCF8523 Real Time Clock for Raspberry Pi                  41
# 4097    ADXL343 - Triple-Axis Accelerometer (+-2g/4g/8g/16g) w/ I2C/SPI            40
# 1697    Bluefruit LE - Bluetooth Low Energy (BLE 4.0) - nRF8001 Breakout           37
# 746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates                28
# 3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2                 23
# 1455    Adafruit 12-Channel 16-bit PWM LED Driver - SPI Interface                  23
# 3787    Adafruit 1.54" 240x240 Wide Angle TFT LCD Display with MicroSD             22
# 3316    Adafruit VL6180X Time of Flight Distance Ranging Sensor (VL6180)           22
# 4224    Adafruit eInk Breakout Friend with 32KB SRAM                               20
# 3134    Adafruit 15x7 CharliePlex LED Matrix Display FeatherWing - Red             20
# 2857    Adafruit Sensirion SHT31-D                                                 19
# 4226    Adafruit INA260 High or Low Side Voltage, Current, Power Sensor            19
# 1982    Adafruit 12-Key Capacitive Touch Sensor Breakout - MPR121                  17
# 1384    GA1A12S202 Log-scale Analog Light Sensor                                   16
# 1411    Adafruit 16-Channel 12-bit PWM/Servo Shield - I2C interface                15
# 2974    LED Charlieplexed Matrix - 9x16 LEDs - Cool White                          15
# 2748    Adafruit ALS-PT19 Analog Light Sensor Breakout                             14
# 2472    Adafruit 9-DOF Absolute Orientation IMU Fusion Breakout - BNO055           13
# 2772    Adafruit Feather M0 Basic Proto - ATSAMD21 Cortex M0                       13
# 2217    Adafruit Audio FX Sound Board + 2x2W Amp - WAV/OGG Trigger -16MB           12
# 1480    2.2" 18-bit color TFT LCD display with microSD card breakout               11
# 2487    Flora Wearable Bluefruit LE Module                                         11
# 1778    Analog Output K-Type Thermocouple Amplifier - AD8495 Breakout              10
# 2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)                  9
# 3072    Adafruit RFM95W LoRa Radio Transceiver Breakout - 868 or 915 MHz            0
# 1980    Adafruit TSL2591 High Dynamic Range Digital Light Sensor                    7
# 3076    Adafruit Feather 32u4 RFM69HCW Packet Radio - 868 or 915 MHz                6
# 2946    Adafruit 16x9 Charlieplexed PWM LED Matrix Driver - IS31FL3731              6
# 3249    Adafruit NeoPXL8 FeatherWing for Feather M0 - 8 x DMA NeoPixels!            5
# 3309    Adafruit CP2104 Friend - USB to Serial Converter                            5
# 2923    Adafruit Latching Mini Relay FeatherWing                                    5
# 4172    Adafruit HUZZAH32 â ESP32 Breakout Board                                  4
# 2927    DC Motor + Stepper FeatherWing Add-on For All Feather Boards                4
# 3650    Adafruit INA219 FeatherWing                                                 4
# 2094    JTAG (2x10 2.54mm) to SWD (2x5 1.27mm) Cable Adapter Board                  4
# 2479    Adafruit Bluefruit LE UART Friend - Bluetooth Low Energy (BLE)              4
# 1651    2.8" TFT Touch Shield for Arduino with Resistive Touch Screen               4
# 1947    2.8" TFT Touch Shield for Arduino w/Capacitive Touch                        3
# 3709    Adafruit SGP30 Air Quality Sensor Breakout - VOC and eCO2                   3
# 904     INA219  High Side DC Current Sensor Breakout - 26V Â±3.2A Max               3
# 3660    Adafruit BME680 - Temperature, Humidity, Pressure and Gas Sensor            3
# 4145    Assembled Adafruit Prop-Maker FeatherWing                                   3
# 1580    Resistive Touch Screen to USB Mouse Controller - AR1100                     3
# 2124    Adafruit LiIon/LiPoly Backpack Add-On for Pro Trinket/ItsyBitsy             3
# 1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board                 3
# 2895    Adafruit Non-Latching Mini Relay FeatherWing                                3
# 2019    Adafruit Triple-Axis Accelerometer - Â±2/4/8g @ 14-bit - MMA8451            3
# 3343    Adafruit CRICKIT FeatherWing for any Feather                                2
# 3463    Adafruit Precision NXP 9-DOF Breakout Board                                 2
# 1032    L3GD20H Triple-Axis Gyro Breakout Board - L3GD20/L3G4200 Upgrade            2
# 2345    Adafruit RGB Matrix HAT + RTC for Raspberry Pi - Mini Kit                   2
# 1356    Flora Color Sensor with White Illumination LED - TCS34725                   2
# 2948    LED Charlieplexed Matrix - 9x16 LEDs - Yellow                               2
# 1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket               2
# 3073    Adafruit RFM96W LoRa Radio Transceiver Breakout - 433 MHz                   2
# 2315    Adafruit PiTFT 2.2" HAT Mini Kit - 320x240 2.2" TFT - No Touch              2
# 3013    Adafruit DS3231 Precision RTC Breakout                                      2
# 4090    Adafruit USB C Breakout Board - Downstream Connection                       1
# 4201    Adafruit AirLift â ESP32 WiFi Co-Processor Breakout Board                 1
# 4116    Adafruit PyPortal - CircuitPython Powered Internet Display                  1
# 269     Thermocouple Amplifier MAX31855 breakout board (MAX6675 upgrade)            1
# 3538    Adafruit AMG8833 IR Thermal Camera Breakout                                 1
# 3231    Adafruit LoRa Radio FeatherWing - RFM95W 900 MHz                            1
# 3200    Teensy 3.x Feather Adapter                                                  1
# 466     VCNL4010 Proximity/Light sensor                                             1
# 2746    Adafruit Bluefruit LE Shield - Bluetooth LE for Arduino                     1
# 2327    Adafruit 16-Channel PWM / Servo HAT for Raspberry Pi - Mini Kit             1
# 1381    VS1053 Codec + MicroSD Breakout - MP3/WAV/MIDI/OGG Play + Record            1
# 992     MPL115A2 - I2C Barometric Pressure/Temperature Sensor                       1
# 4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates                 1
#         column total                                                              754
#
#                                                                          Reject %
# part id products name
# 3677    Adafruit ItsyBitsy 32u4 - 5V 16MHz                                 100.0%
# 2305    Adafruit DRV2605L Haptic Motor Controller                          100.0%
# 3966    Adafruit BMP388 - Precision Barometric Pressure and Altimeter      100.0%
# 3386    Adafruit PiRTC - PCF8523 Real Time Clock for Raspberry Pi          100.0%
# 4097    ADXL343 - Triple-Axis Accelerometer (+-2g/4g/8g/16g) w/ I2C/SPI    100.0%
# 1697    Bluefruit LE - Bluetooth Low Energy (BLE 4.0) - nRF8001 Breakout   100.0%
# 746     Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates        100.0%
# 3566    Adafruit CCS811 Air Quality Sensor Breakout - VOC and eCO2         100.0%
# 1455    Adafruit 12-Channel 16-bit PWM LED Driver - SPI Interface          100.0%
# 3787    Adafruit 1.54" 240x240 Wide Angle TFT LCD Display with MicroSD     100.0%
# 3316    Adafruit VL6180X Time of Flight Distance Ranging Sensor (VL6180)   100.0%
# 4224    Adafruit eInk Breakout Friend with 32KB SRAM                       100.0%
# 3134    Adafruit 15x7 CharliePlex LED Matrix Display FeatherWing - Red     100.0%
# 2857    Adafruit Sensirion SHT31-D                                         100.0%
# 4226    Adafruit INA260 High or Low Side Voltage, Current, Power Sensor    100.0%
# 1982    Adafruit 12-Key Capacitive Touch Sensor Breakout - MPR121          100.0%
# 1384    GA1A12S202 Log-scale Analog Light Sensor                           100.0%
# 1411    Adafruit 16-Channel 12-bit PWM/Servo Shield - I2C interface        100.0%
# 2974    LED Charlieplexed Matrix - 9x16 LEDs - Cool White                  100.0%
# 2748    Adafruit ALS-PT19 Analog Light Sensor Breakout                     100.0%
# 2472    Adafruit 9-DOF Absolute Orientation IMU Fusion Breakout - BNO055   100.0%
# 2772    Adafruit Feather M0 Basic Proto - ATSAMD21 Cortex M0               100.0%
# 2217    Adafruit Audio FX Sound Board + 2x2W Amp - WAV/OGG Trigger -16MB   100.0%
# 1480    2.2" 18-bit color TFT LCD display with microSD card breakout       100.0%
# 2487    Flora Wearable Bluefruit LE Module                                 100.0%
# 1778    Analog Output K-Type Thermocouple Amplifier - AD8495 Breakout      100.0%
# 2809    Adafruit LIS3DH Triple-Axis Accelerometer (+-2g/4g/8g/16g)         100.0%
# 3072    Adafruit RFM95W LoRa Radio Transceiver Breakout - 868 or 915 MHz     0.0%
# 1980    Adafruit TSL2591 High Dynamic Range Digital Light Sensor           100.0%
# 3076    Adafruit Feather 32u4 RFM69HCW Packet Radio - 868 or 915 MHz       100.0%
# 2946    Adafruit 16x9 Charlieplexed PWM LED Matrix Driver - IS31FL3731     100.0%
# 3249    Adafruit NeoPXL8 FeatherWing for Feather M0 - 8 x DMA NeoPixels!   100.0%
# 3309    Adafruit CP2104 Friend - USB to Serial Converter                   100.0%
# 2923    Adafruit Latching Mini Relay FeatherWing                           100.0%
# 4172    Adafruit HUZZAH32 â ESP32 Breakout Board                         100.0%
# 2927    DC Motor + Stepper FeatherWing Add-on For All Feather Boards       100.0%
# 3650    Adafruit INA219 FeatherWing                                        100.0%
# 2094    JTAG (2x10 2.54mm) to SWD (2x5 1.27mm) Cable Adapter Board         100.0%
# 2479    Adafruit Bluefruit LE UART Friend - Bluetooth Low Energy (BLE)     100.0%
# 1651    2.8" TFT Touch Shield for Arduino with Resistive Touch Screen      100.0%
# 1947    2.8" TFT Touch Shield for Arduino w/Capacitive Touch               100.0%
# 3709    Adafruit SGP30 Air Quality Sensor Breakout - VOC and eCO2          100.0%
# 904     INA219  High Side DC Current Sensor Breakout - 26V Â±3.2A Max      100.0%
# 3660    Adafruit BME680 - Temperature, Humidity, Pressure and Gas Sensor   100.0%
# 4145    Assembled Adafruit Prop-Maker FeatherWing                          100.0%
# 1580    Resistive Touch Screen to USB Mouse Controller - AR1100            100.0%
# 2124    Adafruit LiIon/LiPoly Backpack Add-On for Pro Trinket/ItsyBitsy    100.0%
# 1782    MCP9808 High Accuracy I2C Temperature Sensor Breakout Board        100.0%
# 2895    Adafruit Non-Latching Mini Relay FeatherWing                       100.0%
# 2019    Adafruit Triple-Axis Accelerometer - Â±2/4/8g @ 14-bit - MMA8451   100.0%
# 3343    Adafruit CRICKIT FeatherWing for any Feather                       100.0%
# 3463    Adafruit Precision NXP 9-DOF Breakout Board                        100.0%
# 1032    L3GD20H Triple-Axis Gyro Breakout Board - L3GD20/L3G4200 Upgrade   100.0%
# 2345    Adafruit RGB Matrix HAT + RTC for Raspberry Pi - Mini Kit          100.0%
# 1356    Flora Color Sensor with White Illumination LED - TCS34725          100.0%
# 2948    LED Charlieplexed Matrix - 9x16 LEDs - Yellow                      100.0%
# 1770    2.8" TFT LCD with Touchscreen Breakout Board w/MicroSD Socket      100.0%
# 3073    Adafruit RFM96W LoRa Radio Transceiver Breakout - 433 MHz          100.0%
# 2315    Adafruit PiTFT 2.2" HAT Mini Kit - 320x240 2.2" TFT - No Touch     100.0%
# 3013    Adafruit DS3231 Precision RTC Breakout                             100.0%
# 4090    Adafruit USB C Breakout Board - Downstream Connection              100.0%
# 4201    Adafruit AirLift â ESP32 WiFi Co-Processor Breakout Board        100.0%
# 4116    Adafruit PyPortal - CircuitPython Powered Internet Display         100.0%
# 269     Thermocouple Amplifier MAX31855 breakout board (MAX6675 upgrade)   100.0%
# 3538    Adafruit AMG8833 IR Thermal Camera Breakout                        100.0%
# 3231    Adafruit LoRa Radio FeatherWing - RFM95W 900 MHz                   100.0%
# 3200    Teensy 3.x Feather Adapter                                         100.0%
# 466     VCNL4010 Proximity/Light sensor                                    100.0%
# 2746    Adafruit Bluefruit LE Shield - Bluetooth LE for Arduino            100.0%
# 2327    Adafruit 16-Channel PWM / Servo HAT for Raspberry Pi - Mini Kit    100.0%
# 1381    VS1053 Codec + MicroSD Breakout - MP3/WAV/MIDI/OGG Play + Record   100.0%
# 992     MPL115A2 - I2C Barometric Pressure/Temperature Sensor              100.0%
# 4279    Adafruit Ultimate GPS with USB - 66 channel w/10 Hz updates        100.0%
#         column total                                                        99.0%

# %% [markdown]
# # In-Stock
# In-Stock % = 1 - (Out of Stock / Total Stock)

# %%
date_start = str(np.min(fab_data_main['wo date created']).date())

stock_super_main = pd.read_sql(
'''
SELECT
DATE(timestamp) AS date,
sku_id,
visible_stock
FROM sku_stock_snapshots
WHERE sku_id IN (SELECT sku_id FROM skus WHERE bom_type = 'pnp' AND sku_status = 'working')
AND DATE(timestamp) BETWEEN ' '''+ date_start +''' ' AND ' '''+ week_end +''' '
''', db)

col_fix(stock_super_main)

# %%
# this sql table is a snapshot of each part every 6 hours, so 4 per day
# get the average per part per day so we have just one number
stock_main = stock_super_main.groupby(['date','sku id'], as_index = False)[['visible stock']].mean()

# round it
stock_main['visible stock'] = [int(np.round(x)) for x in stock_main['visible stock']]

# flag the skus and days out of stock (OOS)
stock_main['oos'] = np.where(stock_main['visible stock'] == 0, 1, 0)

# get additional date columns
stock_main['week ending'] = stock_main['date'].map(dict(zip(weeks['date'], weeks['week ending'])))

# get all the opportunities to be out of stock
# then get all the actual out of stock
df1 = stock_main.groupby('week ending').agg({'oos':'sum','sku id':['count','nunique']})
df1.columns = df1.columns.droplevel(0)

df1.rename(columns = {'sum':'agg oos',
                      'count':'agg sku count',
                      'nunique':'unique sku count'}, inplace = True)

# take the ratio to get % in stock and % out of stock
df1['out-of-stock %'] = df1['agg oos']/df1['agg sku count']
df1['in-stock %'] = 1 - df1['out-of-stock %']

stock = df1.copy()

# %%
df1
# Out:
#              agg oos  agg sku count  unique sku count  out-of-stock %  \
# week ending
# 2014-12-04         9            468               117        0.019231
# 2014-12-11         9            820               118        0.010976
# 2014-12-18         3            832               120        0.003606
# 2014-12-25         3            843               121        0.003559
# 2015-01-01         6            847               121        0.007084
# 2015-01-08        10            847               121        0.011806
# 2015-01-15        22            854               122        0.025761
# 2015-01-22        28            861               124        0.032520
# 2015-01-29        62            868               124        0.071429
# 2015-02-05        51            868               124        0.058756
# 2015-02-12        62            868               124        0.071429
# 2015-02-19        41            868               124        0.047235
# 2015-02-26        62            872               126        0.071101
# 2015-03-05        90            882               126        0.102041
# 2015-03-12        80            882               126        0.090703
# 2015-03-19        82            888               128        0.092342
# 2015-03-26        66            896               128        0.073661
# 2015-04-02        66            896               128        0.073661
# 2015-04-09        40            911               131        0.043908
# 2015-04-16        38            920               132        0.041304
# 2015-04-23        38            531               133        0.071563
# 2015-04-30        48            940               135        0.051064
# 2015-05-07        56            952               136        0.058824
# 2015-05-14        75            952               136        0.078782
# 2015-05-21        75            952               136        0.078782
# 2015-05-28        62            952               136        0.065126
# 2015-06-04        75            954               137        0.078616
# 2015-06-11        32            959               137        0.033368
# 2015-06-18        36            961               138        0.037461
# 2015-06-25        12            966               138        0.012422
# 2015-07-02        12            968               139        0.012397
# 2015-07-09        27            977               141        0.027636
# 2015-07-16        27            991               143        0.027245
# 2015-07-23        23           1001               143        0.022977
# 2015-07-30        29           1008               144        0.028770
# 2015-08-06        28           1008               144        0.027778
# 2015-08-13        34           1008               144        0.033730
# 2015-08-20        64           1036               154        0.061776
# 2015-08-27       104           1078               154        0.096475
# 2015-09-03       189           1169               167        0.161677
# 2015-09-10       186           1177               171        0.158029
# 2015-09-17       184           1197               171        0.153718
# 2015-09-24       191           1197               171        0.159566
# 2015-10-01       195           1200               172        0.162500
# 2015-10-08       178           1221               176        0.145782
# 2015-10-15       168           1232               176        0.136364
# 2015-10-22       131           1232               176        0.106331
# 2015-10-29        94           1238               177        0.075929
# 2015-11-05        97           1253               180        0.077414
# 2015-11-12       188           1260               180        0.149206
# 2015-11-19       190           1260               180        0.150794
# 2015-11-26       188           1260               180        0.149206
# 2015-12-03       197           1260               180        0.156349
# 2015-12-10       153           1266               182        0.120853
# 2015-12-17       159           1285               188        0.123735
# 2015-12-24       152           1322               192        0.114977
# 2015-12-31       136           1367               196        0.099488
# 2016-01-07        63           1375               197        0.045818
# 2016-01-14        67           1383               198        0.048445
# 2016-01-21        68           1386               198        0.049062
# 2016-01-28        82           1387               199        0.059120
# 2016-02-04        85           1403               201        0.060584
# 2016-02-11        72           1407               201        0.051173
# 2016-02-18        93           1414               202        0.065771
# 2016-02-25        86           1414               202        0.060820
# 2016-03-03       103           1414               202        0.072843
# 2016-03-10       100           1414               202        0.070721
# 2016-03-17       147           1420               204        0.103521
# 2016-03-24       138           1428               204        0.096639
# 2016-03-31       123           1428               204        0.086134
# 2016-04-07       125           1484               212        0.084232
# 2016-04-14       154           1504               215        0.102394
# 2016-04-21       156           1505               215        0.103654
# 2016-04-28       136           1505               215        0.090365
# 2016-05-05       119           1517               221        0.078444
# 2016-05-12       130           1549               223        0.083925
# 2016-05-19       158           1567               225        0.100830
# 2016-05-26       172           1583               229        0.108654
# 2016-06-02       156           1610               232        0.096894
# 2016-06-09       135           1624               232        0.083128
# 2016-06-16       150           1624               232        0.092365
# 2016-06-23       112           1624               232        0.068966
# 2016-06-30       112           1638               234        0.068376
# 2016-07-07        90           1638               234        0.054945
# 2016-07-14        58           1649               237        0.035173
# 2016-07-21        66           1659               237        0.039783
# 2016-07-28        82           1666               238        0.049220
# 2016-08-04        71           1666               238        0.042617
# 2016-08-11        54           1674               242        0.032258
# 2016-08-18        62           1698               243        0.036514
# 2016-08-25        44           1704               244        0.025822
# 2016-09-01        41           1711               245        0.023963
# 2016-09-08        46           1718               246        0.026775
# 2016-09-15        47           1725               247        0.027246
# 2016-09-22        58           1729               247        0.033545
# 2016-09-29        57           1729               247        0.032967
# 2016-10-06        48           1729               247        0.027762
# 2016-10-13        66           1729               247        0.038172
# 2016-10-20        60           1739               249        0.034503
# 2016-10-27        73           1755               252        0.041595
# 2016-11-03        63           1779               256        0.035413
# 2016-11-10        43           1799               258        0.023902
# 2016-11-17        41           1806               258        0.022702
# 2016-11-24        79           1806               258        0.043743
# 2016-12-01        74           1806               258        0.040975
# 2016-12-08        59           1806               258        0.032669
# 2016-12-15        87           1806               258        0.048173
# 2016-12-22        87           1806               258        0.048173
# 2016-12-29        83           1806               258        0.045958
# 2017-01-05        54           1806               258        0.029900
# 2017-01-12        78           1807               259        0.043165
# 2017-01-19        54           1813               259        0.029785
# 2017-01-26        62           1835               264        0.033787
# 2017-02-02        81           1855               265        0.043666
# 2017-02-09        67           1855               265        0.036119
# 2017-02-16        76           1858               267        0.040904
# 2017-02-23        92           1881               271        0.048910
# 2017-03-02        85           1897               271        0.044808
# 2017-03-09       102           1904               272        0.053571
# 2017-03-16       106           1913               275        0.055410
# 2017-03-23        89           1927               276        0.046186
# 2017-03-30        82           1932               276        0.042443
# 2017-04-06        87           1932               276        0.045031
# 2017-04-13        79           1940               278        0.040722
# 2017-04-20        83           1955               280        0.042455
# 2017-04-27        83           1961               281        0.042325
# 2017-05-04        82           1967               281        0.041688
# 2017-05-11        82           1971               282        0.041603
# 2017-05-18        83           1974               282        0.042047
# 2017-05-25        78           1978               283        0.039434
# 2017-06-01        79           1982               284        0.039859
# 2017-06-08        88           1995               286        0.044110
# 2017-06-15        83           2005               287        0.041397
# 2017-06-22        87           2009               287        0.043305
# 2017-06-29        80           2009               287        0.039821
# 2017-07-06        97           2041               293        0.047526
# 2017-07-13       105           2051               293        0.051195
# 2017-07-20       105           2051               293        0.051195
# 2017-07-27        15            293               293        0.051195
# 2017-08-03        54           1172               293        0.046075
# 2017-08-10       117           2067               297        0.056604
# 2017-08-17       104           2080               298        0.050000
# 2017-08-24        85           2089               299        0.040689
# 2017-08-31        83           2096               300        0.039599
# 2017-09-07        73           2107               301        0.034646
# 2017-09-14        86           2124               305        0.040490
# 2017-09-21        98           2135               305        0.045902
# 2017-09-28       102           2142               307        0.047619
# 2017-10-05        91           2149               307        0.042345
# 2017-10-12        96           2151               308        0.044630
# 2017-10-19        63           1243               311        0.050684
# 2017-10-26       102           2179               312        0.046810
# 2017-11-02        95           2193               315        0.043320
# 2017-11-09        97           2208               317        0.043931
# 2017-11-16       108           2222               318        0.048605
# 2017-11-23       110           2234               320        0.049239
# 2017-11-30       108           2240               320        0.048214
# 2017-12-07       103           2240               320        0.045982
# 2017-12-14        91           2243               321        0.040571
# 2017-12-21        97           2251               323        0.043092
# 2017-12-28       105           2261               323        0.046440
# 2018-01-04       107           2265               325        0.047241
# 2018-01-11       122           2282               326        0.053462
# 2018-01-18       113           2282               326        0.049518
# 2018-01-25       115           2285               327        0.050328
# 2018-02-01       115           2293               329        0.050153
# 2018-02-08       125           2310               331        0.054113
# 2018-02-15       134           2323               332        0.057684
# 2018-02-22       128           2325               333        0.055054
# 2018-03-01       125           2334               334        0.053556
# 2018-03-08       132           2338               334        0.056459
# 2018-03-15       144           2352               336        0.061224
# 2018-03-22       140           2362               339        0.059272
# 2018-03-29       152           2373               339        0.064054
# 2018-04-05       141           2373               339        0.059418
# 2018-04-12       121           2373               339        0.050990
# 2018-04-19       112           2374               340        0.047178
# 2018-04-26       109           2380               340        0.045798
# 2018-05-03        89           2380               340        0.037395
# 2018-05-10        98           2392               344        0.040970
# 2018-05-17       126           2416               346        0.052152
# 2018-05-24       130           2431               348        0.053476
# 2018-05-31       118           2436               348        0.048440
# 2018-06-07       121           2436               348        0.049672
# 2018-06-14       105           2436               348        0.043103
# 2018-06-21        93           2444               350        0.038052
# 2018-06-28        96           2450               350        0.039184
# 2018-07-05        89           2454               352        0.036267
# 2018-07-12        91           2464               352        0.036932
# 2018-07-19        97           2475               354        0.039192
# 2018-07-26        97           2478               354        0.039144
# 2018-08-02       101           2486               357        0.040628
# 2018-08-09       141           2520               360        0.055952
# 2018-08-16       133           2526               362        0.052652
# 2018-08-23       156           2546               366        0.061273
# 2018-08-30       179           2562               366        0.069867
# 2018-09-06       175           2562               366        0.068306
# 2018-09-13       169           2567               368        0.065836
# 2018-09-20       173           2591               373        0.066770
# 2018-09-27       181           2619               375        0.069110
# 2018-10-04       183           2643               378        0.069240
# 2018-10-11       170           2647               379        0.064224
# 2018-10-18       186           2658               381        0.069977
# 2018-10-25       188           2677               385        0.070228
# 2018-11-01       195           2695               385        0.072356
# 2018-11-08       185           2695               385        0.068646
# 2018-11-15       178           2707               389        0.065755
# 2018-11-22       185           2734               391        0.067666
# 2018-11-29       177           2739               393        0.064622
# 2018-12-06       181           2758               394        0.065627
# 2018-12-13       188           2758               394        0.068165
# 2018-12-20       175           2765               395        0.063291
# 2018-12-27       188           2765               395        0.067993
# 2019-01-03       180           2772               396        0.064935
# 2019-01-10       203           2802               403        0.072448
# 2019-01-17       223           2826               405        0.078910
# 2019-01-24       227           2837               407        0.080014
# 2019-01-31       219           2855               409        0.076708
# 2019-02-07       223           2873               412        0.077619
# 2019-02-14       202           2897               416        0.069727
# 2019-02-21       227           2930               422        0.077474
# 2019-02-28       228           2964               425        0.076923
# 2019-03-07       247           2982               426        0.082830
# 2019-03-14       246           2986               427        0.082384
# 2019-03-21       235           2989               427        0.078622
# 2019-03-28       224           3004               431        0.074567
# 2019-04-04       211           3019               433        0.069891
# 2019-04-11       204           3040               435        0.067105
# 2019-04-18       188           3056               438        0.061518
# 2019-04-25       207           3070               439        0.067427
# 2019-05-02       211           3077               440        0.068573
# 2019-05-09       202           3087               441        0.065436
# 2019-05-16       181           3094               442        0.058500
# 2019-05-23       188           3097               443        0.060704
# 2019-05-30       172           3115               445        0.055217
# 2019-06-06       120           3115               445        0.038523
# 2019-06-13       121           3122               446        0.038757
#
#              in-stock %
# week ending
# 2014-12-04     0.980769
# 2014-12-11     0.989024
# 2014-12-18     0.996394
# 2014-12-25     0.996441
# 2015-01-01     0.992916
# 2015-01-08     0.988194
# 2015-01-15     0.974239
# 2015-01-22     0.967480
# 2015-01-29     0.928571
# 2015-02-05     0.941244
# 2015-02-12     0.928571
# 2015-02-19     0.952765
# 2015-02-26     0.928899
# 2015-03-05     0.897959
# 2015-03-12     0.909297
# 2015-03-19     0.907658
# 2015-03-26     0.926339
# 2015-04-02     0.926339
# 2015-04-09     0.956092
# 2015-04-16     0.958696
# 2015-04-23     0.928437
# 2015-04-30     0.948936
# 2015-05-07     0.941176
# 2015-05-14     0.921218
# 2015-05-21     0.921218
# 2015-05-28     0.934874
# 2015-06-04     0.921384
# 2015-06-11     0.966632
# 2015-06-18     0.962539
# 2015-06-25     0.987578
# 2015-07-02     0.987603
# 2015-07-09     0.972364
# 2015-07-16     0.972755
# 2015-07-23     0.977023
# 2015-07-30     0.971230
# 2015-08-06     0.972222
# 2015-08-13     0.966270
# 2015-08-20     0.938224
# 2015-08-27     0.903525
# 2015-09-03     0.838323
# 2015-09-10     0.841971
# 2015-09-17     0.846282
# 2015-09-24     0.840434
# 2015-10-01     0.837500
# 2015-10-08     0.854218
# 2015-10-15     0.863636
# 2015-10-22     0.893669
# 2015-10-29     0.924071
# 2015-11-05     0.922586
# 2015-11-12     0.850794
# 2015-11-19     0.849206
# 2015-11-26     0.850794
# 2015-12-03     0.843651
# 2015-12-10     0.879147
# 2015-12-17     0.876265
# 2015-12-24     0.885023
# 2015-12-31     0.900512
# 2016-01-07     0.954182
# 2016-01-14     0.951555
# 2016-01-21     0.950938
# 2016-01-28     0.940880
# 2016-02-04     0.939416
# 2016-02-11     0.948827
# 2016-02-18     0.934229
# 2016-02-25     0.939180
# 2016-03-03     0.927157
# 2016-03-10     0.929279
# 2016-03-17     0.896479
# 2016-03-24     0.903361
# 2016-03-31     0.913866
# 2016-04-07     0.915768
# 2016-04-14     0.897606
# 2016-04-21     0.896346
# 2016-04-28     0.909635
# 2016-05-05     0.921556
# 2016-05-12     0.916075
# 2016-05-19     0.899170
# 2016-05-26     0.891346
# 2016-06-02     0.903106
# 2016-06-09     0.916872
# 2016-06-16     0.907635
# 2016-06-23     0.931034
# 2016-06-30     0.931624
# 2016-07-07     0.945055
# 2016-07-14     0.964827
# 2016-07-21     0.960217
# 2016-07-28     0.950780
# 2016-08-04     0.957383
# 2016-08-11     0.967742
# 2016-08-18     0.963486
# 2016-08-25     0.974178
# 2016-09-01     0.976037
# 2016-09-08     0.973225
# 2016-09-15     0.972754
# 2016-09-22     0.966455
# 2016-09-29     0.967033
# 2016-10-06     0.972238
# 2016-10-13     0.961828
# 2016-10-20     0.965497
# 2016-10-27     0.958405
# 2016-11-03     0.964587
# 2016-11-10     0.976098
# 2016-11-17     0.977298
# 2016-11-24     0.956257
# 2016-12-01     0.959025
# 2016-12-08     0.967331
# 2016-12-15     0.951827
# 2016-12-22     0.951827
# 2016-12-29     0.954042
# 2017-01-05     0.970100
# 2017-01-12     0.956835
# 2017-01-19     0.970215
# 2017-01-26     0.966213
# 2017-02-02     0.956334
# 2017-02-09     0.963881
# 2017-02-16     0.959096
# 2017-02-23     0.951090
# 2017-03-02     0.955192
# 2017-03-09     0.946429
# 2017-03-16     0.944590
# 2017-03-23     0.953814
# 2017-03-30     0.957557
# 2017-04-06     0.954969
# 2017-04-13     0.959278
# 2017-04-20     0.957545
# 2017-04-27     0.957675
# 2017-05-04     0.958312
# 2017-05-11     0.958397
# 2017-05-18     0.957953
# 2017-05-25     0.960566
# 2017-06-01     0.960141
# 2017-06-08     0.955890
# 2017-06-15     0.958603
# 2017-06-22     0.956695
# 2017-06-29     0.960179
# 2017-07-06     0.952474
# 2017-07-13     0.948805
# 2017-07-20     0.948805
# 2017-07-27     0.948805
# 2017-08-03     0.953925
# 2017-08-10     0.943396
# 2017-08-17     0.950000
# 2017-08-24     0.959311
# 2017-08-31     0.960401
# 2017-09-07     0.965354
# 2017-09-14     0.959510
# 2017-09-21     0.954098
# 2017-09-28     0.952381
# 2017-10-05     0.957655
# 2017-10-12     0.955370
# 2017-10-19     0.949316
# 2017-10-26     0.953190
# 2017-11-02     0.956680
# 2017-11-09     0.956069
# 2017-11-16     0.951395
# 2017-11-23     0.950761
# 2017-11-30     0.951786
# 2017-12-07     0.954018
# 2017-12-14     0.959429
# 2017-12-21     0.956908
# 2017-12-28     0.953560
# 2018-01-04     0.952759
# 2018-01-11     0.946538
# 2018-01-18     0.950482
# 2018-01-25     0.949672
# 2018-02-01     0.949847
# 2018-02-08     0.945887
# 2018-02-15     0.942316
# 2018-02-22     0.944946
# 2018-03-01     0.946444
# 2018-03-08     0.943541
# 2018-03-15     0.938776
# 2018-03-22     0.940728
# 2018-03-29     0.935946
# 2018-04-05     0.940582
# 2018-04-12     0.949010
# 2018-04-19     0.952822
# 2018-04-26     0.954202
# 2018-05-03     0.962605
# 2018-05-10     0.959030
# 2018-05-17     0.947848
# 2018-05-24     0.946524
# 2018-05-31     0.951560
# 2018-06-07     0.950328
# 2018-06-14     0.956897
# 2018-06-21     0.961948
# 2018-06-28     0.960816
# 2018-07-05     0.963733
# 2018-07-12     0.963068
# 2018-07-19     0.960808
# 2018-07-26     0.960856
# 2018-08-02     0.959372
# 2018-08-09     0.944048
# 2018-08-16     0.947348
# 2018-08-23     0.938727
# 2018-08-30     0.930133
# 2018-09-06     0.931694
# 2018-09-13     0.934164
# 2018-09-20     0.933230
# 2018-09-27     0.930890
# 2018-10-04     0.930760
# 2018-10-11     0.935776
# 2018-10-18     0.930023
# 2018-10-25     0.929772
# 2018-11-01     0.927644
# 2018-11-08     0.931354
# 2018-11-15     0.934245
# 2018-11-22     0.932334
# 2018-11-29     0.935378
# 2018-12-06     0.934373
# 2018-12-13     0.931835
# 2018-12-20     0.936709
# 2018-12-27     0.932007
# 2019-01-03     0.935065
# 2019-01-10     0.927552
# 2019-01-17     0.921090
# 2019-01-24     0.919986
# 2019-01-31     0.923292
# 2019-02-07     0.922381
# 2019-02-14     0.930273
# 2019-02-21     0.922526
# 2019-02-28     0.923077
# 2019-03-07     0.917170
# 2019-03-14     0.917616
# 2019-03-21     0.921378
# 2019-03-28     0.925433
# 2019-04-04     0.930109
# 2019-04-11     0.932895
# 2019-04-18     0.938482
# 2019-04-25     0.932573
# 2019-05-02     0.931427
# 2019-05-09     0.934564
# 2019-05-16     0.941500
# 2019-05-23     0.939296
# 2019-05-30     0.944783
# 2019-06-06     0.961477
# 2019-06-13     0.961243

# %% [markdown]
# ### Stock summary

# %%
fmt = ['n0'] * 3 + ['p1'] * 2

print(jb_mean(stock.iloc[-53:], fmt))

stock.tail(8).format_(fmt)
# Out:
#                    mean
# Agg Oos             176
# Agg Sku Count     2,774
# Unique Sku Count    397
# Out-Of-Stock %     6.3%
# In-Stock %        93.7%
#             Agg Oos Agg Sku Count Unique Sku Count Out-Of-Stock % In-Stock %
# week ending
# 2019-04-25      207         3,070              439           6.7%      93.3%
# 2019-05-02      211         3,077              440           6.9%      93.1%
# 2019-05-09      202         3,087              441           6.5%      93.5%
# 2019-05-16      181         3,094              442           5.9%      94.1%
# 2019-05-23      188         3,097              443           6.1%      93.9%
# 2019-05-30      172         3,115              445           5.5%      94.5%
# 2019-06-06      120         3,115              445           3.9%      96.1%
# 2019-06-13      121         3,122              446           3.9%      96.1%

# %% [markdown]
# ### In-Stock plot

# %%
fig, ax = plt.subplots(figsize = (20,5))

n = 16 # plot the most recent 16 weeks
x = range(n)
y1 = stock['in-stock %'].tail(n)

ax.plot(x, y1,
       lw = 5,
       ls = '--',
       marker = 'o',
       mew = 5,
       color = colors[1])

ax.set_xticks(x)
ls = list(qual.index[-n:])
ls2 = list(jb_dates(pd.Series(ls), 'date xticks'))
ax.set_xticklabels(ls2, fontsize = 15, rotation = 0)
ax.set_xlabel('Week Ending', fontsize = 20, labelpad = 15)
ax.grid(alpha = 0.25)
ax.set_yticklabels(['{:,.1f}%'.format(x * 100) for x in ax.get_yticks()], fontsize = 20)
ax.set_title('In-Stock %', fontsize = 30, y = 1.02)
ax.legend().set_visible(False)
ax.set_facecolor(colors[0])

plt.savefig(image_path + ax.get_title(), bbox_inches = 'tight')
plt.show()

# %% [markdown]
# ### Get all part names, for reference

# %%
sku_names = pd.read_sql(
'''
SELECT
DISTINCT sku_name AS sku_name,
sku_id,
part_id,
sku_status,
bom_type
FROM skus
WHERE sku_id IN '''+ str(tuple(stock_main['sku id'].unique())) +'''
GROUP BY sku_name
''', db)

col_fix(sku_names)

# %% [markdown]
# # Fab Op Metric
# After getting each metric alone, let's put them altogether, weight them, and calculate the Fab Op Metric

# %%
# here are our weights, as determined by the Fab department
weights = {'availability':1.5/10,
           'quality'      :2/10,
           'rework'       :0.5/10, # least important = lowest weight
           'in-stock'     :6/10} # most important = heaviest weight

# check to make sure they sum to one
if sum(weights.values()) != 1:
    print('check this')

# get all metrics
df1 = avail[['availability %']]
df2 = qual[['quality %']]
df3 = rework[['success %']]
df4 = stock[['in-stock %']]

# join them all
df5 = df1.join(df2).join(df3).join(df4)

# rename columns and index
df5.columns = weights.keys()
df5.index.name = 'week ending'

# get each metric times its weight and then sum to get overall Fab Op Metric
df5['fab op metric'] = np.sum(df5 * list(weights.values()), axis = 1)
df5.fillna(0, inplace = True)

# get current week
df6 = df5.iloc[[-1]].T
df6.columns = ['week ending ' + week_end]

# get the avg
df7 = pd.DataFrame(df5.iloc[-53:].mean())
df7.columns = ['avg']

# get weights
df8 = pd.DataFrame.from_dict(weights, orient = 'index')
df8.columns = ['weight']

df9 = df6.join(df7).join(df8)

df9['above or below the avg'] = np.where(df9['week ending ' + week_end] < df9['avg'], 'below','ABOVE')

df10 = df9.copy()
df10.index = [x.title() for x in df10.index]
df10.reset_index(inplace = True)
df10.rename(columns = {'index':'metric'}, inplace = True)

fmt = [0] + ['p1'] * 3 + [0]
display(df10.format_(fmt).replace('nan%',''))
report_dict['summary - fab op metric table'] = df10.format_(fmt).replace('nan%','').to_html(index = False)
# Out:
#           Metric Week Ending 2019-06-13    Avg Weight Above Or Below The Avg
# 0   Availability                  74.1%  98.0%  15.0%                  below
# 1        Quality                  97.6%  99.3%  20.0%                  below
# 2         Rework                   1.0%  44.3%   5.0%                  below
# 3       In-Stock                  96.1%  93.7%  60.0%                  ABOVE
# 4  Fab Op Metric                  88.4%  93.0%                         below

# %% [markdown]
# ### For State of the Fruit notes
# For team leads to copy/paste into their notes for our weekly recurring company-wide meeting

# %%
last_week = str(df5.iloc[-2:].index[0].date())
this_week = str(df5.iloc[-2:].index[1].date())

ls = []
ls.append('fab ops!')
for i in df9.index:
    val1 = df5.loc[this_week][i] * 100
    val2 = df5.loc[last_week][i] * 100
    
    if i.title() == 'Fab Op Metric':
        val3 = df10[df10['metric'] == i.title()]['avg'].values[0] * 100
        i = 'overall'
        wrt = '-' + i + ': {:,.1f}% (last week: {:,.1f}%, goal = {:,.1f}%)'.format(val1, val2, val3)
        ls.append(wrt)
    else:    
        wrt = '-' + i + ': {:,.1f}% (last week: {:,.1f}%)'.format(val1, val2)
        ls.append(wrt)
    
report_dict['sotf blurb'] = '<br>'.join(ls)

print('\n'.join(ls))
# Out:
# fab ops!
# -availability: 74.1% (last week: 69.4%)
# -quality: 97.6% (last week: 98.9%)
# -rework: 1.0% (last week: 0.0%)
# -in-stock: 96.1% (last week: 96.1%)
# -overall: 88.4% (last week: 87.9%, goal = 93.0%)

# %% [markdown]
# ### Fab Op Plot

# %%
n = 53
chart = df5.iloc[-n:]
rows = len(chart.columns)

fig, axes = plt.subplots(nrows = rows, ncols = 1, figsize = (20,30))
for i in range(rows):
    x = range(n)
    y = chart[chart.columns[i]]
    axes[i].plot(x,y,
                 lw = 5,
                 marker = 'o',
                 mew = 5,
                 color = colors[i+1])
    axes[i].grid()
    axes[i].set_xticks(range(n))
    axes[i].set_facecolor(colors[0])
    
    name = chart.columns[i]
    if name in ['quality','in-stock']:
        p = '{:,.1f}%'
    else:
        p = '{:,.0f}%'
           
    axes[i].set_yticklabels([p.format(x * 100) for x in axes[i].get_yticks()], fontsize = 20)
    axes[i].legend().set_visible(False)
    axes[i].set_title(name.title(), fontsize = 25)
    axes[i].set_xticklabels('')
    
    m = df9.loc[name, 'avg']
    axes[i].axhline(m, ls = '--', color = colors[5], lw = 5, alpha = 0.65)
    
axes[i].set_xticks(range(n))
ls = [str(x) for x in chart.index.date]
axes[-1].set_xticklabels(ls, fontsize = 10, rotation = 270)    
axes[-1].set_xlabel('Week Ending', fontsize = 20, labelpad = 20)

title = 'Fab Op Metric with Averages'
plt.suptitle(title, fontsize = 30, y = 0.92)

fig.savefig(image_path + title, bbox_inches = 'tight')
plt.show()

# %% [markdown]
# *****
# # Excel
# *****

# %% [markdown]
# ### Set up workbook

# %%
workbook = xlsxwriter.Workbook(csv_path + workbook_title + '.xlsx',
                               {'nan_inf_to_errors': True,
                               'strings_to_numbers': True})

tabs = ['Fab Op Table',
       'Completed',
       'Active',
       'Pending',
       'Completed Wos With Null Dates',
       'Skus Used for In-stock Metric',
       'Rejection Data',
       'Current Reworks']

#=========================
# Formats
#=========================

title = workbook.add_format({'font_size':25,
                             'font_name':'Arial (Bold)'})

subtitle = workbook.add_format({'font_size':15,
                                 'font_name':'Arial (Bold)'})


col_names = workbook.add_format({'font_name':'Arial (Bold)',
                                 'font_color':'white',
                                 'valign':'vcenter',
                                 'align':'center',
                                 'bg_color':colors[3],
                                 'bottom':1,
                                 'top':1,
                                 'left':1,
                                 'right':1})

percent = workbook.add_format({'num_format':'0.0%'})
number = workbook.add_format({'num_format':'#,##0'})
dummy = workbook.add_format({'font_color':'black'})
date = workbook.add_format({'num_format':'yyyy-mm-dd'})

for tab in tabs:
    workbook.add_worksheet(tab) # create each tab

my_worksheets = {}
for sht in workbook.worksheets():
    my_worksheets[sht.get_name()] = sht # create dict like tab_name:worksheet_instance

#=========================
# Apply same formatting to each worksheet
#=========================

for k, v in my_worksheets.items():
    sht = my_worksheets[k]
    sht.write(0, 0,
              k.title(),
              title)
    sht.write(1, 0,
              workbook_title,
              subtitle)

# %% [markdown]
# ### Fab Op Table

# %%
sht = my_worksheets['Fab Op Table']

fmt = {'metric':dummy,
       'week ending ' + week_end:percent,
       'avg':percent,
       'weight':percent,
       'above or below the avg':dummy}

start_row = 3
start_col = 0

df = df10.copy()
df.replace([np.nan,np.inf], '', inplace = True)

for i in range(len(df.columns)):
    sht.write(start_row,
              start_col + i,
              df.columns[i].title(),
              col_names)

    len1 = [len(str(x)) for x in df.iloc[:, i]]
    len2 = [len(df.columns[i])]
    len3 = np.max(len1 + len2)

    sht.set_column(start_col + i,
                   start_col + i,
                   len3)

    for j in range(len(df)):
        sht.write(start_row + 1 + j, 
                  start_col + i,
                  df.iloc[j,i],
                  fmt[df.columns[i]])

# %% [markdown]
# ### Completed, Active, Pending

# %%
cols = ['wo id',
       'wo id string',
       'wo date created',
       'wo date scheduled',
       'wo date active',
       'wo date completed',
       'sku id',
       'part id',
       'products name',
       'wo qty in',
       'wo qty out',
       'wo qty reject',
       'wo status',
       'wo substatus']


for_csv = fab_data_main[cols].drop_duplicates('wo id').copy()

# %%
for c in ['completed','active','pending']:
    
    sht = my_worksheets[c.title()]
    
    df = for_csv[for_csv['wo status'] == c].copy()   
    
    for col in ['created','scheduled','active','completed']:
        df['wo date ' + col] = pd.to_datetime(df['wo date ' + col])    
        
    df.replace([np.nan,np.inf], '', inplace = True)
    
    fmt = {'wo qty in':number,
           'wo qty out':number,
           'wo qty reject':number,
           
           'wo date created':date,
           'wo date active':date,
           'wo date scheduled':date,
           'wo date completed':date,}
    
    for i in range(len(df.columns)):
        sht.write(start_row,
                  start_col + i,
                  df.columns[i].title(),
                  col_names)

        len1 = [len(str(x)) for x in df.iloc[:, i]]
        len2 = [len(df.columns[i])]
        len3 = np.max(len1 + len2)

        sht.set_column(start_col + i,
                       start_col + i,
                       len3)

        for j in range(len(df)):
            sht.write(start_row + 1 + j, 
                      start_col + i,
                      df.iloc[j,i],
                      fmt[df.columns[i]] if df.columns[i] in list(fmt.keys()) else dummy)

# %% [markdown]
# ### Completed Wos With Null Dates

# %%
sht = my_worksheets['Completed Wos With Null Dates']

df = date_nulls.iloc[:, :14]

for col in ['created','scheduled','active','completed']:
    df['wo date ' + col] = pd.to_datetime(df['wo date ' + col])    

df.replace([np.nan,np.inf], '', inplace = True)

fmt = {'wo qty in':number,
       'wo qty out':number,
       'wo qty reject':number,

       'wo date created':date,
       'wo date active':date,
       'wo date scheduled':date,
       'wo date completed':date,}

for i in range(len(df.columns)):
    sht.write(start_row,
              start_col + i,
              df.columns[i].title(),
              col_names)

    len1 = [len(str(x)) for x in df.iloc[:, i]]
    len2 = [len(df.columns[i])]
    len3 = np.max(len1 + len2)

    sht.set_column(start_col + i,
                   start_col + i,
                   len3)

    for j in range(len(df)):
        sht.write(start_row + 1 + j, 
                  start_col + i,
                  df.iloc[j,i],
                  fmt[df.columns[i]] if df.columns[i] in list(fmt.keys()) else dummy)

# %% [markdown]
# ### Skus Used for In-stock Metric

# %%
sht = my_worksheets['Skus Used for In-stock Metric']

df = sku_names

for i in range(len(df.columns)):
    sht.write(start_row,
              start_col + i,
              df.columns[i].title(),
              col_names)

    len1 = [len(str(x)) for x in df.iloc[:, i]]
    len2 = [len(df.columns[i])]
    len3 = np.max(len1 + len2)

    sht.set_column(start_col + i,
                   start_col + i,
                   len3)

    for j in range(len(df)):
        sht.write(start_row + 1 + j, 
                  start_col + i,
                  df.iloc[j,i])

# %% [markdown]
# ### Rejection data

# %%
sht = my_worksheets['Rejection Data']

df = rej2.copy()

c = df.columns.tolist()
f = [number] * len(c)
fmt = dict(zip(c,f))

df.reset_index(inplace = True)

for i in range(len(df.columns)):
    sht.write(start_row,
              start_col + i,
              df.columns[i].title(),
              col_names)

    len1 = [len(str(x)) for x in df.iloc[:, i]]
    len2 = [len(df.columns[i])]
    len3 = np.max(len1 + len2)

    sht.set_column(start_col + i,
                   start_col + i,
                   len3)

    for j in range(len(df)):
        sht.write(start_row + 1 + j, 
                  start_col + i,
                  df.iloc[j,i],
                  fmt[df.columns[i]] if df.columns[i] in list(fmt.keys()) else dummy)

# %% [markdown]
# ### Current Reworks

# %%
sht = my_worksheets['Current Reworks']

df = cur_reworks.copy()
df.reset_index(inplace = True)

fmt = {'qty attempted':number,
       'qty rejected':number,
       'reject %':percent}

for i in range(len(df.columns)):
    sht.write(start_row,
              start_col + i,
              df.columns[i].title(),
              col_names)

    len1 = [len(str(x)) for x in df.iloc[:, i]]
    len2 = [len(df.columns[i])]
    len3 = np.max(len1 + len2)

    sht.set_column(start_col + i,
                   start_col + i,
                   len3)

    for j in range(len(df)):
        sht.write(start_row + 1 + j, 
                  start_col + i,
                  df.iloc[j,i],
                  fmt[df.columns[i]] if df.columns[i] in list(fmt.keys()) else dummy)

# %%
if workbook_close == 'yes':
    workbook.close()

# %% [markdown]
# # Time from WO creation to completion

# %%
six_months_ago = str((pd.to_datetime(week_end) - pd.DateOffset(months = 6)).date())

# choose your columns

ls = ['wo id',
      'wo date created',
      'wo date scheduled',
      'wo date active',
      'wo date completed',
      'process time start',
      'process time end',
      'spa time start',
      'spa time end']

# exclude outsourced and get only completed WOs
for_time = fab_data_main[(fab_data_main['wo outsourced'] == 'no')
              & (fab_data_main['wo status'] == 'completed')][ls].copy()

# change to datetime
for col in ['created','scheduled','active','completed']:
    for_time['wo date ' + col] = pd.to_datetime(for_time['wo date ' + col], errors = 'coerce')
    
# get data from 6 months ago only    
for_time = for_time[for_time['wo date completed'] >= six_months_ago].copy()

# create to scheduled
df1 = for_time.drop_duplicates('wo id').copy()
df1['created to scheduled'] = (df1['wo date scheduled'] - df1['wo date created']).dt.days * 86400
df1['created to scheduled'].dropna(inplace = True)

# scheduled to active
df2 = for_time.drop_duplicates('wo id').copy()
df2['scheduled to active'] = (df2['wo date active'] - df2['wo date scheduled']).dt.days * 86400

# active to completed
df3 = for_time.drop_duplicates('wo id').copy()
df3['active to completed'] = (df2['wo date completed'] - df2['wo date active']).dt.days * 86400

# put it all together
by_wo = pd.merge(df1[['wo id','created to scheduled']],
                 df2[['wo id','scheduled to active']],
                 how = 'left',
                 on = 'wo id').merge(df3[['wo id','active to completed']],
                                    how = 'left',
                                    on = 'wo id')

# map the week completed
by_wo['wo week completed'] = by_wo['wo id'].map(dict(zip(fab_data_main['wo id'], fab_data_main['wo week completed'])))
by_wo.sort_values('wo week completed', inplace = True)

t = len(by_wo[by_wo['wo week completed'] == week_end])

print('x{} work orders were completed during week ending {}.'.format(t, week_end))

# avg time elapsed per WO for the latest week
a = pd.DataFrame(by_wo[by_wo['wo week completed'] == week_end].drop(['wo id','wo week completed'], 1).mean()/86400)

d = week_end
y = d[:4]
m = calendar.month_abbr[int(d[5:7])]
dy = d[-2:]

per = 'week ending ' + m + ' ' + dy + ', ' + y     
a.columns = [per]

# avg time elapsed per WO for all weeks in the last 6 months
b = pd.DataFrame(by_wo.drop(['wo id','wo week completed'], 1).mean()/86400)
b.columns = ['6 month avg']

c = a.join(b)
c.index.names = ['Period']
c.index = [x.title() for x in c.index]

for col in c.columns:
    c[col] = [int(np.round(x)) for x in c[col]]
    
ls = []
for index, row in c.iterrows():
    if np.abs(row[0] - row[1]) < 2:
        ret = 'About Equal'
    else:
        if row[0] < row[1]:
            ret = 'Shorter'
        else:
            ret = 'Longer'
    ls.append(ret)
    
c['shorter or longer than avg?'] = ls    

c.columns = c.columns.str.title()

print('The table below is the avg time, per work order, that it takes to go from period to period (measured in days)')
display(c)

report_dict['wo times table'] = c.to_html(index = True)
# Out:
# x20 work orders were completed during week ending 2019-06-13.
# The table below is the avg time, per work order, that it takes to go from period to period (measured in days)
#                       Week Ending Jun 13, 2019  6 Month Avg  \
# Created To Scheduled                        49           54
# Scheduled To Active                          0            1
# Active To Completed                         72           42
#
#                      Shorter Or Longer Than Avg?
# Created To Scheduled                     Shorter
# Scheduled To Active                  About Equal
# Active To Completed                       Longer

# %% [markdown]
# *****
# # PDF report
# *****

# %%
ls1 = ['came to',
      'amounted to',
      'reached',
      'totaled',
      'equalled',
      'arrived at',
      'achieved']

ls2 = ['above',
      'higher',
      'greater than',
      'larger than',
      'surpassing',
      'passing',
      'exceeding']

ls3 = ['below',
      'under',
      'less than',
      'beneath',
      'underneath',
      'lower than',
      'short of']

ls4 = ['about equal to']

# %% [markdown]
# ### Report Availability

# %%
i = np.random.randint(len(ls1))

a = int(avail.iloc[-1]['scheduled'])
b = int(avail.iloc[-1]['active'])
c = int(avail.iloc[-1]['completed'])

cur = avail.iloc[-1]['availability %']
avg = df10[df10['metric'] == 'Availability']['avg'].values[0]

if np.abs(cur - avg) <= 0.01:
    w = 'about equal to'
else:
    if cur < avg:
        w = ls3[i]
    else:
        w = ls2[i]

wrt1 = 'This metric {} {:,.1f}%, {} the average of {:,.1f}%.'.format(ls1[i], cur * 100, w, avg * 100)
wrt2 = 'x{} work orders were scheduled, x{} went active, and x{} were completed. \
The chart below shows these counts over time along with the Availability Metric.'.format(a,b,c)

report_dict['avail - summary write'] = wrt1 + ' ' + wrt2

# %% [markdown]
# ### Report Quality

# %%
i = np.random.randint(len(ls1))

cur = qual.iloc[-1]['quality %']
avg = df10[df10['metric'] == 'Quality']['avg'].values[0]

if np.abs(cur - avg) <= 0.01:
    w = 'about equal to'
else:
    if cur < avg:
        w = ls3[i]
    else:
        w = ls2[i]

wrt = 'This metric {} {:,.1f}%, {} the average of {:,.1f}%.'.format(ls1[i], cur * 100, w, avg * 100)
report_dict['quality - summary write'] = wrt

# %% [markdown]
# ### Report Machine Yield

# %%
i = np.random.randint(len(ls1))

cur = qual.iloc[-1]['machine yield']
avg = qual['machine yield'].mean()

if np.abs(cur - avg) <= 0.001:
    w = 'about equal to'
else:
    if cur < avg:
        w = ls3[i]
    else:
        w = ls2[i]

wrt = 'Zooming in now to the Fabrication step, we have Machine Yield, which {} {:,.1f}%, {} the average of \
{:,.1f}%.'.format(ls1[i], cur * 100, w, avg * 100)
report_dict['quality - machine yield write'] = wrt

# %% [markdown]
# ### Report Rework

# %%
i = np.random.randint(len(ls1))

cur = rework.iloc[-1]['success %']
avg = df10[df10['metric'] == 'Rework']['avg'].values[0]

if np.abs(cur - avg) <= 0.01:
    w = 'about equal to'
else:
    if cur < avg:
        w = ls3[i]
    else:
        w = ls2[i]
        
a = int(rework.iloc[-1]['qty attempted'])
b = int(rework.iloc[-1]['qty out'])
        
if a == 0:
    add = ', because no reworks were attempted.'
else:
    add = '. x{:,.0f} units were attempted and x{:,.0f} were successful.'.format(a,b)

wrt = 'This metric {} {:,.1f}%, {} the average of {:,.1f}%'.format(ls1[i], cur * 100, w, avg * 100) + add
report_dict['rework - summary write'] = wrt

# %% [markdown]
# ### Report In-Stock

# %%
i = np.random.randint(len(ls1))

unique_sku_count = int(stock.iloc[-1]['unique sku count'])
report_dict['in-stock - unique sku count'] = unique_sku_count

cur = stock.iloc[-1]['in-stock %']
avg = df10[df10['metric'] == 'In-Stock']['avg'].values[0]

if np.abs(cur - avg) <= 0.01:
    w = 'about equal to'
else:
    if cur < avg:
        w = ls3[i]
    else:
        w = ls2[i]
        
wrt = 'This metric {} {:,.1f}%, {} the average of {:,.1f}%, and below is a chart showing this metric over time.'.format(ls1[i], cur * 100, w, avg * 100)        
report_dict['in-stock - summary write'] = wrt

# %% [markdown]
# # PDF Start

# %%
if pdf_write == 'yes':
    
    data_link = 'https://www.dropbox.com/sh/st80djvfp77ccbd/AAAh8mXioFzdi1_zhZq2N7Tqa?dl=0'
    report_title = 'w.e. ' + week_end + ' - Fab Op Report.pdf'        
    
    from jinja2 import Environment, FileSystemLoader
    env = Environment(loader = FileSystemLoader(html_path))

    template = env.get_template(html_title)

    template_vars = {'week_end':week_end,
                     'now':pretty_now,
                     
                     'summary_fab_op_metric_table':report_dict['summary - fab op metric table'],
                     'data_link':data_link,
                     
                     'sotf_blurb':report_dict['sotf blurb'],
                     
                     'summary_work_order_counts':report_dict['summary - work order counts'],
                     'avail_summary_write':report_dict['avail - summary write'],
                    
                     'quality_summary_write':report_dict['quality - summary write'],
                     'quality_high_rejection_write':report_dict['quality - high rejection write'],
                    
                     'quality_machine_yield_write':report_dict['quality - machine yield write'],
                    
                     'rework_summary_write':report_dict['rework - summary write'],
                    
                     'unique_sku_count':report_dict['in-stock - unique sku count'],
                     'in_stock_summary_write':report_dict['in-stock - summary write'],
                    
                     'wo_times_table':report_dict['wo times table'],
                    
                     'tilde':tilde}

    html_out = template.render(template_vars)

    from weasyprint import HTML
    HTML(string = html_out).write_pdf(pdf_path + report_title,
                                      stylesheets = [style_sheet_path])

# %%
print('done')
# Out:
# done
