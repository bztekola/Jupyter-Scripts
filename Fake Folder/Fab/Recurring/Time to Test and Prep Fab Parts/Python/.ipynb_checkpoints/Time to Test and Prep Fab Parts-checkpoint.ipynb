# %% [markdown]
# ### Change this stuff

# %%
# do you want to run the script AND write the CSV? or just run the script?
# the script will run regardless of what you choose here.
# choose "yes" or "no".
close_workbook = 'yes'

# %% [markdown]
# ### Libraries

# %%
import os
tilde = os.path.expanduser('~')

import sys
sys.path.insert(0, tilde + '/Scripts/Fake Folder/Python Libraries')

from jb_libraries import *
# %matplotlib inline

# %% [markdown]
# ### Script settings

# %%
csv_path = tilde + '/Scripts/Fake Folder/Fab/Recurring/Time to Test and Prep Fab Parts/CSVs/'

# %%
n = 90
now = dt.datetime.now().date()
x_days_ago = (now - pd.DateOffset(days = n)).date()

date_start = str(x_days_ago)
date_end = str(now)

print('Data is from {} to {}, which is {} days'.format(date_start,date_end,n))
# Out:
# Data is from 2019-03-19 to 2019-06-17, which is 90 days

# %%
workbook_title = 'Previous 90 days ending {} - Time to Test and Prep Fab Parts'.format(date_end)

# %% [markdown]
# ### Get data

# %%
processes_main = pd.read_sql(
'''
SELECT
process_id,
wo_id,
process_group
FROM processes
WHERE DATE(time_start) BETWEEN ' '''+ date_start +''' ' AND ' '''+ date_end +''' ' 
AND wo_id != 0 # to exclude reworks
AND process_group IN ('test','prep','secondary') # get only these groups
AND time_end != '0000-00-00 00:00:00' # to exclude open processes
''', db)

col_fix(processes_main)

# %%
p = list(set(processes_main['process id']))

sp_actions_main = pd.read_sql(
'''
SELECT
process_id,
spa_qty,
spa_time_start,
spa_time_end
FROM sp_actions
WHERE process_id IN '''+ str(tuple(p)) +'''
''', db)

col_fix(sp_actions_main)

e = sp_actions_main['spa time end'] - sp_actions_main['spa time start']
minutes = (e.dt.days * 24 * 60 * 60 + e.dt.seconds)/60
sp_actions_main['time elapsed in minutes'] = minutes

# %%
skus_main = pd.read_sql(
'''
SELECT
sku_id,
k.part_id,
pd.products_name
FROM skus k
LEFT JOIN products_description pd ON k.part_id = pd.part_id
''', db)

col_fix(skus_main)

# %%
w = list(set(processes_main['wo id']))

work_orders_main = pd.read_sql(
'''
SELECT
wo_id,
sku_id,
wo_qty AS work_order_qty
FROM work_orders 
WHERE wo_id IN '''+ str(tuple(w)) +'''
AND wo_status = 'completed' # only include completed WOs
''', db)

col_fix(work_orders_main)

for c in ['part id','products name']:
    work_orders_main[c] = work_orders_main['sku id'].map(dict(zip(skus_main['sku id'], skus_main[c])))
    
work_orders_main['products name'].fillna('no part name', inplace = True)

# %% [markdown]
# ### Structure it

# %%
main = sp_actions_main.copy()

# map from processes_main
cols = processes_main.columns.tolist()
cols.remove('process id')
for c in cols:
    main[c] = main['process id'].map(dict(zip(processes_main['process id'],processes_main[c])))
    
# map from work_orders_main    
cols = work_orders_main.columns.tolist()
cols.remove('wo id')
for c in cols:
    main[c] = main['wo id'].map(dict(zip(work_orders_main['wo id'],work_orders_main[c])))
    
# check nulls    
n = main[main.isnull().any(1)]
if n.empty == True: # if there are no nulls, move on
    pass
else: # if there are nulls, check the wo_status of these wo_ids; if the statuses are anything but "completed", move on
    
    n_ls = list(set(n['wo id']))

    check = pd.read_sql(
    '''
    SELECT
    wo_status,
    COUNT(*) AS count
    FROM work_orders
    WHERE wo_id IN '''+ str(tuple(n_ls)) +'''
    ''', db)

    col_fix(check)    

    count = 0
    for index, row in check.iterrows():
        count += row['count']
        if row['wo status'] == 'completed':
            raise ValueError('check your nulls')

            if count != len(n_ls): # if the count of nulls from your df matches that in the db, move on
                raise ValueError('check your nulls')

main.dropna(inplace = True)
main.reset_index(drop = True, inplace = True)

# %% [markdown]
# ### Get time elapsed

# %%
time = main.groupby('part id')[['time elapsed in minutes']].sum()

# %% [markdown]
# ### Get WO qty

# %%
wo_qty = work_orders_main.groupby('part id')[['work order qty']].sum()

# %% [markdown]
# ### Get Wo Ids

# %%
a1 = work_orders_main[['part id','wo id']].drop_duplicates()
a2 = a1.groupby('part id')['wo id'].apply(lambda x: ', '.join(x.map(str)))
wo_ids = pd.DataFrame(a2)
wo_ids.columns = ['wo ids']

# %% [markdown]
# ### Data by part

# %%
by_part = time.join(wo_qty).join(wo_ids)
by_part.reset_index(inplace = True)
by_part['part id'] = by_part['part id'].map(int)

by_part['products name'] = by_part['part id'].map(dict(zip(main['part id'], main['products name'])))
    
by_part['min per'] = by_part['time elapsed in minutes']/by_part['work order qty']

l1 = 'https://volcano.adafruit.com/volcano/ada_plm.php?/Parts/'
l2 = '/PartProfile/'

by_part['link'] = l1 + by_part['part id'].map(str) + l2

# %% [markdown]
# ### Rearrange columns and sort

# %%
new_cols = ['part id',
            'products name',
            'wo ids',
            'time elapsed in minutes',
            'work order qty',
            'min per',
            'link']

old_cols = by_part.columns.tolist()

s1 = set(old_cols)
s2 = set(new_cols)
s3 = s1.symmetric_difference(s2)

if len(s3) != 0:
    raise ValueError('check ur columns')
else:
    by_part = by_part[new_cols]
    
by_part.sort_values('time elapsed in minutes', ascending = False, inplace = True)

# %%
by_part.head()
# Out:
#      part id                                                  products name  \
# 7        746    Adafruit Ultimate GPS Breakout - 66 channel w/10 Hz updates
# 76      2995                               Adafruit Feather M0 Bluefruit LE
# 28      1651  2.8" TFT Touch Shield for Arduino with Resistive Touch Screen
# 4        284                                           FTDI Friend + extras
# 121     4000                Adafruit Metro M4 Express AirLift (WiFi) - Lite
#
#          wo ids  time elapsed in minutes  work order qty   min per  \
# 7    8044, 8512              2968.333333            4177  0.710638
# 76         8057              1620.616667            1007  1.609351
# 28         8334              1602.300000             390  4.108462
# 4          8573              1461.733333             760  1.923333
# 121  8629, 8686              1324.066667             328  4.036789
#
#                                                                           link
# 7     https://volcano.adafruit.com/volcano/ada_plm.php?/Parts/746/PartProfile/
# 76   https://volcano.adafruit.com/volcano/ada_plm.php?/Parts/2995/PartProfile/
# 28   https://volcano.adafruit.com/volcano/ada_plm.php?/Parts/1651/PartProfile/
# 4     https://volcano.adafruit.com/volcano/ada_plm.php?/Parts/284/PartProfile/
# 121  https://volcano.adafruit.com/volcano/ada_plm.php?/Parts/4000/PartProfile/

# %% [markdown]
# ### Find outliers by time elapsed

# %%
for_outliers = main.groupby('process group').agg({'time elapsed in minutes':['mean','std']})
for_outliers.columns = for_outliers.columns.droplevel(0)
for_outliers['upper'] = for_outliers['mean'] + 3 * for_outliers['std']
for_outliers.reset_index(inplace = True)

def find_outlier(df):
    
    group = df['process group']
    time = df['time elapsed in minutes']
    upper = for_outliers[for_outliers['process group'] == group]['upper'].item()
    
    if time > upper:
        return 'yes'
    else:
        return 'no'
    
main['outlier'] = main.apply(find_outlier, axis = 1)

# %%
print('outliers below')
main[main['outlier'] == 'yes'].sort_values(['process group','time elapsed in minutes'], ascending = [False,False])
# Out:
# outliers below
#       process id  spa qty      spa time start        spa time end  \
# 1183      186819      100 2019-05-21 09:39:34 2019-05-21 15:57:35
# 1118      184534      154 2019-05-22 07:56:49 2019-05-22 14:07:48
# 196       169667      210 2019-04-11 08:14:17 2019-04-11 12:46:28
# 845       179381       70 2019-05-06 11:37:09 2019-05-06 15:43:04
# 677       176681      120 2019-04-26 08:07:55 2019-04-26 12:12:32
# 496       174490      300 2019-05-08 11:35:58 2019-05-08 15:35:34
# 870       179985      170 2019-05-14 09:29:00 2019-05-14 13:17:46
# 641       176559      450 2019-05-07 09:17:07 2019-05-07 13:02:49
# 853       179694      155 2019-04-11 11:04:44 2019-04-11 14:42:39
# 1179      185902       46 2019-05-21 11:05:28 2019-05-21 14:40:26
# 1068      182576      143 2019-05-08 09:05:30 2019-05-08 12:37:02
# 625       176553       83 2019-04-12 11:11:41 2019-04-12 14:38:09
# 1014      181638       69 2019-05-14 09:08:19 2019-05-14 12:31:33
# 1192      186948      245 2019-05-21 08:08:28 2019-05-21 12:05:43
# 436       173797      250 2019-05-16 11:12:18 2019-05-16 14:15:44
# 679       176682      164 2019-04-29 08:05:07 2019-04-29 10:52:21
# 437       173797      283 2019-05-17 08:10:18 2019-05-17 10:53:56
# 763       177691       40 2019-05-06 11:48:56 2019-05-06 14:28:06
# 130       169071      100 2019-05-09 11:02:22 2019-05-09 13:33:09
# 582       175387       50 2019-04-09 14:13:41 2019-04-09 16:41:18
# 210       169668      100 2019-04-26 14:02:09 2019-04-26 16:28:51
# 770       178046      102 2019-04-19 11:06:50 2019-04-19 13:29:57
# 634       176554       60 2019-04-16 12:02:23 2019-04-16 14:24:12
# 637       176554       54 2019-05-13 08:45:27 2019-05-13 10:51:11
#
#       time elapsed in minutes  wo id process group   sku id  work order qty  \
# 1183               378.016667   8796          test  13380.0           150.0
# 1118               370.983333   8686          test  13500.0           208.0
# 196                272.183333   8057          test   8935.0          1007.0
# 845                245.916667   8479          test  12921.0           136.0
# 677                244.616667   8342          test  12652.0           186.0
# 496                239.600000   8245          test   8571.0           800.0
# 870                228.766667   8496          test  13331.0           624.0
# 641                225.700000   8335          test   8644.0          1150.0
# 853                217.916667   8488          test  11943.0           511.0
# 1179               214.966667   8634          test  12652.0           108.0
# 1068               211.533333   8612          test  13428.0           270.0
# 625                206.466667   8334          test   8556.0           390.0
# 1014               203.233333   8578          test  12479.0           270.0
# 1192               237.250000   8802          prep  13050.0           264.0
# 436                183.433333   8221          prep   9702.0           950.0
# 679                167.233333   8342          prep  12652.0           186.0
# 437                163.633333   8221          prep   9702.0           950.0
# 763                159.166667   8399          prep  11286.0           180.0
# 130                150.783333   8041          prep   8911.0           504.0
# 582                147.616667   8290          prep  12619.0           199.0
# 210                146.700000   8057          prep   8935.0          1007.0
# 770                143.116667   8417          prep  12701.0           102.0
# 634                141.816667   8334          prep   8556.0           390.0
# 637                125.733333   8334          prep   8556.0           390.0
#
#       part id                                                   products name  \
# 1183   4242.0  Adafruit PyGamer for MakeCode Arcade, CircuitPython or Arduino
# 1118   4000.0                 Adafruit Metro M4 Express AirLift (WiFi) - Lite
# 196    2995.0                                Adafruit Feather M0 Bluefruit LE
# 845    4116.0      Adafruit PyPortal - CircuitPython Powered Internet Display
# 677    3382.0                      Adafruit Metro M4 feat. Microchip ATSAMD51
# 496    1713.0  Electret Microphone Amplifier - MAX9814 with Auto Gain Control
# 870    4172.0                      Adafruit HUZZAH32 â ESP32 Breakout Board
# 641    1982.0       Adafruit 12-Key Capacitive Touch Sensor Breakout - MPR121
# 853    3800.0                Adafruit ItsyBitsy M4 Express featuring ATSAMD51
# 1179   3382.0                      Adafruit Metro M4 feat. Microchip ATSAMD51
# 1068   4201.0     Adafruit AirLift â ESP32 WiFi Co-Processor Breakout Board
# 625    1651.0   2.8" TFT Touch Shield for Arduino with Resistive Touch Screen
# 1014    781.0            Adafruit USB + Serial LCD Backpack Add-On with Cable
# 1192   3957.0                           Adafruit CRICKIT HAT for Raspberry Pi
# 436    2857.0                                      Adafruit Sensirion SHT31-D
# 679    3382.0                      Adafruit Metro M4 feat. Microchip ATSAMD51
# 437    2857.0                                      Adafruit Sensirion SHT31-D
# 763    3211.0                     Adafruit RGB Matrix Bonnet for Raspberry Pi
# 130    2923.0                        Adafruit Latching Mini Relay FeatherWing
# 582    1947.0            2.8" TFT Touch Shield for Arduino w/Capacitive Touch
# 210    2995.0                                Adafruit Feather M0 Bluefruit LE
# 770    2466.0                              Adafruit METRO 328 without Headers
# 634    1651.0   2.8" TFT Touch Shield for Arduino with Resistive Touch Screen
# 637    1651.0   2.8" TFT Touch Shield for Arduino with Resistive Touch Screen
#
#      outlier
# 1183     yes
# 1118     yes
# 196      yes
# 845      yes
# 677      yes
# 496      yes
# 870      yes
# 641      yes
# 853      yes
# 1179     yes
# 1068     yes
# 625      yes
# 1014     yes
# 1192     yes
# 436      yes
# 679      yes
# 437      yes
# 763      yes
# 130      yes
# 582      yes
# 210      yes
# 770      yes
# 634      yes
# 637      yes

# %% [markdown]
# ### Check it

# %%
# check nulls
n = by_part[by_part.isnull().any(1)]
if n.empty == False:
    raise ValueError('check ur nulls')
    
# qty totals    
t1 = work_orders_main['work order qty'].sum()
t2 = by_part['work order qty'].sum()

if t1 - t2 != 0:
    raise ValueError('check ur totals')    
    
# part count
s1 = set(work_orders_main['part id'])
s2 = set(by_part['part id'])

if len(s1) != len(s2):
    raise ValueError('check ur part count')

# %% [markdown]
# *****
# # Excel
# *****

# %% [markdown]
# ### Set up workbook

# %%
workbook = xlsxwriter.Workbook(csv_path + workbook_title + '.xlsx',
                               {'nan_inf_to_errors': True,
                               'strings_to_numbers': True})

tabs = ['Data By Part']

#=========================
# Formats
#=========================

colors = ['#343635',
          '#2e4874',
          '#7eaba4',
          '#928c85',
          '#347c83',
          '#bfb9d6']
colors = colors * 2

title = workbook.add_format({'font_size':25,
                             'font_name':'Arial (Bold)'})

subtitle = workbook.add_format({'font_size':15,
                                'font_name':'Arial (Bold)'})

col_names = workbook.add_format({'font_name':'Arial (Bold)',
                                 'font_color':'white',
                                 'valign':'vcenter',
                                 'align':'center',
                                 'bg_color':colors[2],
                                 'bottom':1,
                                 'top':1,
                                 'left':1,
                                 'right':1})

right_align = workbook.add_format({'align':'right'})

number = workbook.add_format({'num_format':'#,##0'})
number2 = workbook.add_format({'num_format':'#,##0.0'})
dummy = workbook.add_format({'font_color':'black'})

for tab in tabs:
    workbook.add_worksheet(tab) # create each tab

my_worksheets = {}
for sht in workbook.worksheets():
    my_worksheets[sht.get_name()] = sht # create dict like tab_name:worksheet_instance

#=========================
# Apply same formatting to each worksheet
#=========================

for k, v in my_worksheets.items():
    sht = my_worksheets[k]
    sht.write(0, 0,
              k.title(),
              title)
    sht.write(1, 0,
              workbook_title,
              subtitle)

# %% [markdown]
# ### Write worksheets

# %%
sht = my_worksheets['Data By Part']

fmt = {'time elapsed in minutes':number,
      'work order qty':number,
      'min per':number2,
      'wo ids':right_align}

df = by_part.copy()

start_row = 3
start_col = 0

#=========================
# disclaimer 01
#=========================

ls = list(set(main['process group']))
w = '*times are summed over the '
for i in range(len(ls)):
    if i != len(ls) - 1:
        w += ls[i] + ', '
    else:
        w += 'and ' + ls[i] + ' steps, and the data only includes completed work orders.'
        
sht.write(start_row - 1,
         start_col,
         w)

#=========================
# data
#=========================

for i in range(len(df.columns)):
    sht.write(start_row + 1,
              start_col + i,
              df.columns[i].title(),
              col_names)

    len1 = [len(str(x)) for x in df.iloc[:, i]]
    len2 = [len(df.columns[i])]
    len3 = np.max(len1 + len2)

    sht.set_column(start_col + i,
                   start_col + i,
                   len3)

    for j in range(len(df)):
        sht.write(start_row + 2 + j, 
                  start_col + i,
                  df.iloc[j,i],
                  fmt[df.columns[i]] if df.columns[i] in list(fmt.keys()) else dummy)
        
if close_workbook == 'yes':
    workbook.close()

# %%
print('done')
# Out:
# done
