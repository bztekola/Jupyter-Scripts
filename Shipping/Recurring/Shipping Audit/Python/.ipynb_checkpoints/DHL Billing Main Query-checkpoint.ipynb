# %%
import sys
sys.path.insert(0,'/Users/jarad')

from jb_libraries import *
# %matplotlib inline

# %%
df = pd.DataFrame({'ok':[1,2,3,4]})

# %%
df.format_(['m2'])
# Out:
#       Ok
# 0  $1.00
# 1  $2.00
# 2  $3.00
# 3  $4.00

# %%
pd.read_sql('''show columns from orders''', db)
# Out:
#                           Field                 Type Null  Key Default  \
# 0                     orders_id              int(11)   NO  PRI    None
# 1                   orders_fake  tinyint(3) unsigned   NO            0
# 2                  customers_id              int(11)   NO  MUL       0
# 3                customers_name          varchar(64)   NO  MUL
# 4             customers_company          varchar(32)  YES         None
# 5      customers_street_address          varchar(64)   NO
# 6              customers_suburb          varchar(32)  YES         None
# 7                customers_city          varchar(32)   NO
# 8            customers_postcode          varchar(10)   NO
# 9               customers_state          varchar(32)  YES         None
# 10            customers_country          varchar(64)   NO
# 11          customers_telephone          varchar(32)   NO  MUL
# 12      customers_email_address          varchar(96)   NO  MUL
# ...
