# %% [markdown]
# # Load libraries

# %%
import sys
sys.path.insert(0, '/Users/jarad')

import pandas as pd
import numpy as np

from db2 import *

import xlsxwriter
import calendar
import datetime as dt

import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Get vendor data

# %%
vendors_main = pd.read_sql(
'''
SELECT
stuff_manufacturers_name AS vendor,
LOWER(sm_shipping_location) AS country
FROM stuff_manufacturers
WHERE stuff_manufacturers_name IN 
(SELECT po_source_name FROM purchase_orders WHERE po_date_created BETWEEN '2016-01-01' AND CURRENT_DATE())
''', db)

# %%
vendors = vendors_main.copy()
vendors = vendors.drop_duplicates('vendor')

china = vendors[vendors['country'].str.contains('china|taiwan|hong kong|shenzhen|dongguan|guangdong')]

# %%
#china.to_csv('Chinese and Taiwanese Vendors.csv', index = False)
